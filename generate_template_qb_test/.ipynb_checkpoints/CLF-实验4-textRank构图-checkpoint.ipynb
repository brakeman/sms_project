# %% [raw]
# textRank 取到核心词汇；
# 构图：rankTextNode; smsNode; labelNode;
# 一旦我加入labelNode 即为半监督问题；

# %% [raw]
# step1: rankText IO:
#         Input: [(w1, w2) (w1,w4) ... ]
#         Output: G
#
# setp2: G-adj-nodeRank;
# 完成了；
# 接下来：
# 1. 均衡采样各类；
# 2. 半监督设计；
# 3. path_prediction 设计；

# %%
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import networkx as nx
import matplotlib.pyplot as plt

def rollWindPairs(filtered_sents, windowSize=5):
    '''
    filtered_sents: [['token1','token2', ..], [. , . ,], ..]
    '''
    assert isinstance(filtered_sents[0], list)
    token_pairs = []
    for sent in filtered_sents:
        for i, word in enumerate(sent):
            for j in range(i + 1, i + window_size):
                if j >= len(sent):
                    break
                pair = (word, sent[j])
                if pair not in token_pairs:
                    token_pairs.append(pair)
    return token_pairs

def filter_sents(sents, candidate_pos, stop_words):
    '''
    sents:['sms1', 'sms2', ...]
    1. stopword filter ; 
    2. postag filter ; 
    return: [['token1','token2', ..], [. , . ,], ..]
    '''
    sents_new = []
    for i in sents:
        token_lis = i.split()
        token_lis = nltk.pos_tag(token_lis)
        sent = [i[0].lower() for i in token_lis 
                if (i[1] in candidate_pos) and (i[0] not in stop_words)]
        sents_new.append(sent)
    return sents_new

# %%
# step 1; rankText IO:
sents = df3.sms.tolist()

stop_words = set(stopwords.words('english'))
cand_pos = ['NN', 'VBN', 'VBD']
filtered_sents = filter_sents(sents, cand_pos, stop_words)
print('filter processed.')
pathList = rollWindPairs(filtered_sents, windowSize=4)

# %%
G = nx.Graph()
G.add_edges_from(pathList)
# 最Naive的pagerank计算，最朴素的方式没有设置随机跳跃的部分，所以alpha=1
pr_value = nx.pagerank(G, alpha=1)
# print("naive pagerank值是：", pr_value)

# 改进后的pagerank计算，随机跳跃概率为15%，因此alpha=0.85
pr_impro_value = nx.pagerank(G, alpha=0.85)
# print("improved pagerank值是：", pr_impro_value)
# Out:
# naive pagerank值是： {'***********8509': 3.882940720304544e-05, ':9315xxxxxxxxx34': 2.8967206599548866e-05, '₹19': 4.779741333282751e-05, 'xx9761': 3.879051850041342e-05, 'rs.75.55': 4.8570250404078404e-05, 'rs.3,086.07': 3.855689860658096e-05, 'rs.70302.27': 5.78833222510619e-05, 'metro': 0.00014416038258958718, ':5374xxxxxxxxx33': 2.8904451107911154e-05, 'action.': 0.0001152016707177913, 'xxxxxxxxx6838': 3.8807956370374716e-05, 'xxxxxxxxx2677': 2.9100149834435453e-05, 'xxxx623': 7.762013619486514e-05, 'rs.4465.56': 5.8017300620880894e-05, 'rs.512.25': 4.852917947090899e-05, 'rs.64,197.96': 4.84794236421828e-05, 'rs.1562.71': 3.8825561603804e-05, 'rs.98.32': 2.8899377336329465e-05, 'rs.6045.97': 2.9036098503639498e-05, 'rs.28784.93': 4.817772607987389e-05, '-48.13.': 2.899313276245155e-05, 'rs.0633.49': 5.811472199326434e-05, 'rs.4233': 5.7519595224408996e-05, 'xx9209': 4.827063975506868e-05, 'xxxxxxxxxx5037': 3.881682316370629e-05, 'rs.91517.43': 3.8825561603804e-05, 'xx9555': 3.873662973503088e-05, 'rs.770.85': 5.826168555164546e-05, 'xx7636': 5.795637235478356e-05, 'rs.0,036.50': 5.823598856513317e-05, 'rs.70.03': 2.90696140197821e-05, 'xxxxxxxx2821': 3.8807956370374716e-05, 'xxxxxxxxxx6585': 3.8893202213788786e-05, 'xxxx9005': 3.8799717448054754e-05, 'rs.75157.69': 2.9035398384977096e-05, 'xxxxxxxx6234': 3.894209821403314e-05, ':0404xxxxxxxxx45': 2.889441559693316e-05, 'billpay': 7.713548365699893e-05, 'xxxxxxx6589': 3.878668739637004e-05, 'xxxxxxx6255': 3.878923229739023e-05, 'rs.18529': 5.817199399924967e-05, '05-sep-18': 2.9043518982493966e-05, 'rs.713.72': 2.904882297100765e-05, 'rs.254.66': 4.844750308986112e-05, 'mohd': 0.00014422359163099896, 'xx1503': 5.770856436266475e-05, 'no...46029': 4.8350156159158924e-05, 'xxxxxxxx074474': 4.852875603511151e-05, 'rs.052619.59': 5.8133550607621746e-05, 'ppr889001336750': 3.868779680203988e-05, 'rs.4.54.': 2.898453575586417e-05, 'xx7973': 4.8253233866285394e-05, 'rs.7,037.32': 5.80136922549196e-05, 'xxxxxx6048': 3.892896213676694e-05, 'rs.4.': 5.7914282532857856e-05, 'xxxx3909': 5.928842472489505e-05, 'xxxxx880389': 5.7950580815842964e-05, 'xx1095': 8.709992167507564e-05, 'rs.9,593.26': 4.856550113969787e-05, 'pa': 0.0001256142996115491, 'rs.02.06': 4.823652687318894e-05, 'rs.89.74': 4.815808918290248e-05, 'rs.351815.02': 5.8133550607621746e-05, '00-sep-12': 2.9143442638097388e-05, 'xxxxx996619': 3.87512118103661e-05, 'xxxx8456': 5.8247859186808525e-05, 'payment': 0.007939691991505071, 'xx8428': 2.9071249792108608e-05, 'delhi/+vishwas': 3.8574022126120855e-05, 'rs.91351.58)': 4.8403995610202724e-05, 'xxxx1848': 3.857751134154177e-05, 'no.6828064': 4.805491397284151e-05, 'rs.771.92': 5.787255040506307e-05, 'xxxx137': 3.878387013310779e-05, 'xxxx625022': 3.8811176685021924e-05, 'rs.7,477.01': 3.890067305430601e-05, 'rs.0': 0.00028039677496961114, 'rs.602.63': 2.9011378385456418e-05, 'rs.96,428.49': 2.8975886955853794e-05, 'xxxxx401256': 3.89177447951831e-05, 'rs.7,932.45': 3.8802859062748636e-05, 'xx4500': 3.8773263049859736e-05, 'rs.165.48': 5.801659928977161e-05, 'combined': 0.0003543434084914065, 'xxxxxxxxxxxx218': 5.831209813640682e-05, 'rs.2349.83.': 4.82966219770358e-05, 'xxxx6859': 4.857565682213495e-05, 'spln84751679': 4.83058527646492e-05, 'rs.2.97,': 4.788538865108615e-05, 'xxxxxxxx5419': 3.880795637037472e-05, 'xx8443': 5.811273584984438e-05, 'xxxxxx4418': 4.846943633950285e-05, 'xxxxx422112': 4.836992041887124e-05, 'xxxxxxxx1470': 2.8835257733082805e-05, '********4308': 5.8096437866482866e-05, 'rs.52,142.01': 3.8802859062748636e-05, '-6,625.80': 2.905957681562829e-05, 'rs.8,724.65': 5.786201891425212e-05, 'rs.4,169.08': 3.8825561603804e-05, 'xxxxx039443': 3.906747337898026e-05, 'rs.00597.92': 2.898482943515186e-05, 'rs.9.91.': 4.843137684761311e-05, 'xxxxxxxxxxxx7560': 3.8825561603804e-05, 'rs.1496.31': 2.9036098503639498e-05, 'xxxxx307809': 3.890006968326701e-05, 'xxxx2458': 6.787003706001588e-05, 'xxxx2331': 5.928842472489505e-05, 'xxx2338': 3.886377465846293e-05, 'no ...
# improved pagerank值是： {'***********8509': 4.6444461853818636e-05, ':9315xxxxxxxxx34': 3.8001021739997224e-05, '₹19': 4.728119349569366e-05, '-4,062.85': 3.5360620249449946e-05, 'rs.75.55': 5.102693323254441e-05, 'rs.3,086.07': 4.3002551123268766e-05, 'rs.70302.27': 5.837002852376735e-05, 'metro': 0.00012969049503301912, ':5374xxxxxxxxx33': 4.036877076806049e-05, 'action.': 0.00012633005099523656, 'xxxxxxxxx6838': 4.6141912753568336e-05, 'xxxxxxxxx2677': 3.627440102011628e-05, 'xxxx623': 7.530815340676887e-05, 'rs.4465.56': 6.27535375682708e-05, 'rs.512.25': 5.4316846205395014e-05, 'xxxxx984918': 4.494531098978708e-05, 'rs.1562.71': 4.705738590550539e-05, 'rs.98.32': 3.798255930619788e-05, 'rs.6045.97': 3.5990630893563424e-05, 'rs.28784.93': 4.871423383014195e-05, '-48.13.': 3.515845668420493e-05, 'rs.0633.49': 6.167926553668515e-05, 'rs.4233': 5.7803123697521886e-05, 'xx9209': 4.8331511261182026e-05, 'xxxxxxxxxx5037': 4.5534008117244664e-05, 'rs.91517.43': 4.705738590550539e-05, 'xx9555': 4.587489008186306e-05, 'rs.770.85': 6.263352565241055e-05, 'xx7636': 5.767129927623278e-05, 'rs.70.03': 3.550598791719933e-05, 'xxxxxxxx2821': 4.6141912753568336e-05, 'xxxxxxxxxx6585': 4.358140702539219e-05, 'xxxx9005': 4.4506322420454624e-05, 'rs.75157.69': 3.720691818540232e-05, 'xxxxxxxx6234': 4.4104444801989705e-05, ':0404xxxxxxxxx45': 4.031836366336024e-05, 'billpay': 7.105975707910221e-05, 'xxxxxxx6589': 4.556910984965108e-05, 'xxxxxxx6255': 4.56232884492771e-05, 'rs.18529': 6.220260691979662e-05, '05-sep-18': 3.5663375043625015e-05, 'a/c:6433153910808384': 4.339320502585669e-05, 'rs.254.66': 4.949289792398017e-05, 'mohd': 0.00014104611492074507, 'xx1503': 5.867084758973694e-05, 'no...46029': 5.210019153588944e-05, '**95....770': 4.597551365329877e-05, 'xxxxxxxx074474': 5.154314295662871e-05, 'rs.052619.59': 6.138554880971551e-05, 'ppr889001336750': 4.230936276043261e-05, 'rs.4.54.': 3.618756823731198e-05, 'xx7973': 5.093058513476928e-05, 'rs.7,037.32': 5.626026891322979e-05, 'xxxxxx6048': 4.4391922520079386e-05, 'rs.4.': 5.552944842211498e-05, 'xxxx3909': 6.276720557253538e-05, 'xxxxx880389': 5.64769621410841e-05, 'xx1095': 7.841898919285682e-05, 'rs.9,593.26': 5.4340519659608494e-05, 'pa': 0.00010690749012435294, 'rs.02.06': 4.869934371170885e-05, 'rs.89.74': 5.16566011335851e-05, 'rs.351815.02': 6.13855488097155e-05, '00-sep-12': 3.5757525556908265e-05, 'xxxxx996619': 4.2739663491601015e-05, 'xxxx8456': 5.7542571948774595e-05, 'payment': 0.006926448453984358, 'xx8428': 3.8463813383907476e-05, 'delhi/+vishwas': 5.010454119055825e-05, 'xx2029': 4.42227385073936e-05, 'xxxx1848': 4.59615784472707e-05, 'no.6828064': 4.8445481139438276e-05, 'rs.776.16': 4.988917855055172e-05, 'xxxx137': 4.6346863017109754e-05, 'xxxx625022': 4.560710602273295e-05, 'rs.7,477.01': 4.342140239110339e-05, 'rs.0': 0.000232083187088848, 'rs.602.63': 3.55054028116568e-05, 'rs.96,428.49': 3.67312697293196e-05, 'xxxxx401256': 4.4135818385968975e-05, 'rs.7,932.45': 4.279197821397407e-05, 'rs.7485)': 5.7031032446256256e-05, 'rs.165.48': 5.6636964323889964e-05, 'combined': 0.0003299283305021115, 'xxxxxxxxxxxx218': 6.122361593139605e-05, 'rs.2349.83.': 4.919656262328641e-05, 'xxxx6859': 5.264624223907598e-05, 'rs.93187.17': 5.837002852376735e-05, 'rs.2.97,': 5.132458210592604e-05, 'xxxxxxxx5419': 4.6141912753568336e-05, 'xx8443': 5.784065205911801e-05, 'xxxxxx4418': 4.957064460596805e-05, 'xxxxx422112': 5.069316278058691e-05, 'xxxxxxxx1470': 3.831456752994072e-05, '80-99-2740': 6.269067916125969e-05, 'rs.52,142.01': 4.279197821397407e-05, '-6,625.80': 3.5360620249449946e-05, 'rs.8,724.65': 5.656530332903555e-05, 'rs.4,169.08': 4.705738590550539e-05, 'xxxxx039443': 4.540292949042251e-05, 'rs.00597.92': 3.673259238805627e-05, 'xxxxxxxxxxxx7560': 4.705738590550539e-05, 'rs.1496.31': 3.5990630893563424e-05, 'rs.8622.79': 6.146618631778947e-05, 'xxxx2458': 6.896437810874826e-05, 'xxxx2331': 6.276720557253537e-05, 'xxx2338': 4.387374062793016e-05, 'no.xx7767,': 5.6154807854081 ...

# %%
list(sorted(pr_impro_value.items(), key=lambda x: x[1], reverse=True))[:40]
# Out:
# [('credited', 0.03264424239663568),
#  ('debited', 0.02611740565380605),
#  ('no.', 0.02545042390393083),
#  ('a/c', 0.025027943405631713),
#  ('card', 0.01412071394728508),
#  ('rs.', 0.012488636834504822),
#  ('balance', 0.00920398067751928),
#  ('bank', 0.009055778867998394),
#  ('credit', 0.008432791408833025),
#  ('account', 0.008185242563323024),
#  ('avl', 0.007703579277063674),
#  ('payment', 0.006926448453984358),
#  ('linked', 0.005795025466468138),
#  ('rs', 0.005749447586148198),
#  ('inr', 0.005657616340513232),
#  ('ref', 0.005483008859918423),
#  ('bal', 0.0053527301140571006),
#  ('transaction', 0.004941100018924099),
#  ('transfer', 0.004660315508801019),
#  ('amount', 0.0040579966681122724),
#  ('please', 0.003847176481914739),
#  ('cash', 0.0034062030363325654),
#  ('received', 0.0032981674999837357),
#  ('fund', 0.00302618406479073),
#  ('loan', 0.003008429120355924),
#  ('txn', 0.0029901397451497615),
#  ('debit', 0.0028972035810519805),
#  ('customer,', 0.002650268260808924),
#  ('reversal', 0.002630690737537279),
#  ('bal:', 0.0026185080664795964),
#  ('request', 0.0024302179366091224),
#  ('emi', 0.0022539352534700534),
#  ('made', 0.0021169429372077638),
#  ('sent', 0.002029982894003266),
#  ('declined', 0.001932200449139045),
#  ('airtel', 0.0019025782498376435),
#  ('processed', 0.001835062445122348),
#  ('number', 0.0017474691557199092),
#  ('ac', 0.0017253418889624974),
#  ('limit', 0.0016879830626784745)]

# %%
list(sorted(pr_impro_value.items(), key=lambda x: x[1], reverse=True))[:40]

# %%
from collections import OrderedDict
import numpy as np
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
# nlp = spacy.load('en_core_web_sm')

class TextRank4Keyword():
    """Extract keywords from text"""
    
    def __init__(self):
        self.d = 0.85 # damping coefficient, usually is .85
        self.min_diff = 1e-5 # convergence threshold
        self.steps = 10 # iteration steps
        self.node_weight = None # save keywords and its weight

    
    def set_stopwords(self, stopwords):  
        """Set stop words"""
        for word in STOP_WORDS.union(set(stopwords)):
            lexeme = nlp.vocab[word]
            lexeme.is_stop = True
    
    def sentence_segment(self, doc, candidate_pos, lower):
        """Store those words only in cadidate_pos"""
        sentences = []
        for sent in doc.sents:
            selected_words = []
            for token in sent:
                # Store words only with cadidate POS tag
                if token.pos_ in candidate_pos and token.is_stop is False:
                    if lower is True:
                        selected_words.append(token.text.lower())
                    else:
                        selected_words.append(token.text)
            sentences.append(selected_words)
        return sentences
        
    def get_vocab(self, sentences):
        """Get all tokens"""
        vocab = OrderedDict()
        i = 0
        for sentence in sentences:
            for word in sentence:
                if word not in vocab:
                    vocab[word] = i
                    i += 1
        return vocab
    
    def get_token_pairs(self, window_size, sentences):
        """Build token_pairs from windows in sentences"""
        token_pairs = list()
        for sentence in sentences:
            for i, word in enumerate(sentence):
                for j in range(i+1, i+window_size):
                    if j >= len(sentence):
                        break
                    pair = (word, sentence[j])
                    if pair not in token_pairs:
                        token_pairs.append(pair)
        return token_pairs
        
    def symmetrize(self, a):
        return a + a.T - np.diag(a.diagonal())
    
    def get_matrix(self, vocab, token_pairs):
        """Get normalized matrix"""
        # Build matrix
        vocab_size = len(vocab)
        g = np.zeros((vocab_size, vocab_size), dtype='float')
        for word1, word2 in token_pairs:
            i, j = vocab[word1], vocab[word2]
            g[i][j] = 1
            
        # Get Symmeric matrix
        g = self.symmetrize(g)
        
        # Normalize matrix by column
        norm = np.sum(g, axis=0)
        g_norm = np.divide(g, norm, where=norm!=0) # this is ignore the 0 element in norm
        
        return g_norm

    
    def get_keywords(self, number=10):
        """Print top number keywords"""
        node_weight = OrderedDict(sorted(self.node_weight.items(), key=lambda t: t[1], reverse=True))
        for i, (key, value) in enumerate(node_weight.items()):
            print(key + ' - ' + str(value))
            if i > number:
                break
        
        
    def analyze(self, text, 
                candidate_pos=['NOUN', 'PROPN'], 
                window_size=4, lower=False, stopwords=list()):
        """Main function to analyze text"""
        
        # Set stop words
        self.set_stopwords(stopwords)
        
        # Pare text by spaCy
        doc = nlp(text)
        
        # Filter sentences
        sentences = self.sentence_segment(doc, candidate_pos, lower) # list of list of words
        
        # Build vocabulary
        vocab = self.get_vocab(sentences)
        
        # Get token_pairs from windows
        token_pairs = self.get_token_pairs(window_size, sentences)
        
        # Get normalized matrix
        g = self.get_matrix(vocab, token_pairs)
        
        # Initionlization for weight(pagerank value)
        pr = np.array([1] * len(vocab))
        
        # Iteration
        previous_pr = 0
        for epoch in range(self.steps):
            pr = (1-self.d) + self.d * np.dot(g, pr)
            if abs(previous_pr - sum(pr))  < self.min_diff:
                break
            else:
                previous_pr = sum(pr)

        # Get weight for each node
        node_weight = dict()
        for word, index in vocab.items():
            node_weight[word] = pr[index]
        
        self.node_weight = node_weight

# %%
textRank = TextRank4Keyword()

# %%
set_stopwords(stopwords)
doc = nlp(text)

sentences = self.sentence_segment(doc, candidate_pos, lower) # list of list of words
vocab = self.get_vocab(sentences)
token_pairs = self.get_token_pairs(window_size, sentences)


# Get normalized matrix
g = self.get_matrix(vocab, token_pairs)
pr = np.array([1] * len(vocab))
previous_pr = 0
for epoch in range(self.steps):

# %%
import networkx as nx
import matplotlib.pyplot as plt

def build_diGraph(edges):
    """
    初始化图
    :param edges: 存储有向边的列表
    :return: 使用有向边构造完毕的有向图
    """
    G = nx.DiGraph()   # DiGraph()表示有向图
    for edge in edges:
        G.add_edge(edge[0], edge[1])   # 加入边
    return G

if __name__ == '__main__':
    edges = [("A", "B"), ("B", "A"), ("B", "C"), ("C", "B"), ("A", "D"), ("D", "C")]
    G = build_diGraph(edges)

    # 将图形画出
    layout = nx.spring_layout(G)
    nx.draw(G, pos=layout, with_labels=True, hold=False)
    # for index in G.edges_iter(data=True):
    #     print(index)   #输出所有边的节点关系和权重
    plt.show()

    # 最Naive的pagerank计算，最朴素的方式没有设置随机跳跃的部分，所以alpha=1
    pr_value = nx.pagerank(G, alpha=1)
    print("naive pagerank值是：", pr_value)

    # 改进后的pagerank计算，随机跳跃概率为15%，因此alpha=0.85
    pr_impro_value = nx.pagerank(G, alpha=0.85)
    print("improved pagerank值是：", pr_impro_value)
# Out:
# naive pagerank值是： {'D': 0.09999942779541016, 'C': 0.3000001907348633, 'B': 0.40000057220458984, 'A': 0.19999980926513672}
# improved pagerank值是： {'D': 0.12175740572483727, 'C': 0.3017466141876402, 'B': 0.37824259427516266, 'A': 0.1982533858123598}

# %%
df3_te
# Out:
#                                                           sms        cls
# sent_id
# sent_10460  thank you for payment of inr.6000.00 on your c...    交易流水＿转账
# sent_10998  dear customer,your transaction at atm 1cn04401...  账号异常＿余额不足
# sent_11310  your a/c no. xxxxxxx7494 is debited for inr 2,...    交易流水＿转账
# sent_1142   your a/c xxxxxxx5273 has been debited with inr...    交易流水＿转账
# sent_11776  your a/c no. ***********5885 is credited for r...    交易流水＿转账
# sent_1184   inr 9,400.00 credited to your a/c no xxxxxxx49...    交易流水＿转账
# sent_12118  dear boi customer, a/c xxxxxxxxxxx6116 charged...    交易流水＿转账
# sent_12381  rs.30 has been debited from your kotak account...    交易流水＿转账
# sent_1239   a/c nn4214 debited for inr 24; atm wdl. a/c ba...    交易流水＿转账
# sent_12633  dear customer, refund of rs .82 from hpcl 0.75...    交易流水＿转账
# sent_13206  your a/c no. xxxxxxxx1061 is debited for rs.3....    交易流水＿转账
# sent_13481  dear customer, payment received for amount of ...    交易流水＿转账
# sent_13846  your profile password for username xxxaan has ...  账号异常＿卡号冻结
# sent_13944  bill payment for ketaki has been made successf...    交易流水＿转账
# sent_14307  your a/c no. xxxxxx1711 is credited for rs.20....    交易流水＿转账
# sent_14432  pos tran of rs.1522.00 is done on card xx0742 ...    交易流水＿转账
# sent_1457   idbi bk a/c. nnnnn64164 credited rs 8000.00 tw...    交易流水＿转账
# sent_14673  your a/c no. xxxx651 is debited with rs 199.00...    交易流水＿转账
# sent_15051  a/c 3xxxxx6226 debited by rs. 1,500 total bal:...    交易流水＿转账
# sent_15753  your a/c no. xxxxxxxxxxx8248 is debited for rs...    交易流水＿转账
# sent_16041  hello! your a/c no 60313147 has been credited ...    交易流水＿转账
# sent_1655   dear customer, your a/c no. xxxxxxxx9939 is de...    交易流水＿转账
# sent_16565  your debit card ending 1471 has been blocked. ...  账号异常＿卡号冻结
# sent_16602  your fund transfer request for rs. 1000.0 on 2...  账号异常＿扣款失败
# sent_1699   you have initiated a txn of inr 415.68 at irct...    交易流水＿转账
# sent_17046  your ac xxxxx774561 debited inr 60,000.00 on 3...    交易流水＿转账
# sent_17090  hold for inr 10,000.00 created in your ac xxxx...    交易流水＿转账
# sent_17308  dear customer, hold has been placed on your ac...  账号异常＿卡号冻结
# sent_17326  loan of rs. 75000.00 disbursed from loan a/c n...  贷后提醒＿到期提醒
# sent_17349  tds of inr 332.00 deducted for interest paid o...    交易流水＿转账
# ...                                                       ...        ...
# sent_28001  dear customer, a/c xxx1662 charged rs.600 for ...  sms_other
# sent_28068  ur transaction on hdfc bank credit card ending...    交易流水＿转账
# sent_28375  update: inr 25,000.00 debited from a/c xx0830 ...    交易流水＿转账
# sent_28392  dear customer.thank you for your recent paymen...  贷后提醒＿到期提醒
# sent_28495  dear customer,we regret to note that payments ...   信用卡＿还款提醒
# sent_2888   dear customer, total amount due on credit card...   信用卡＿还款提醒
# sent_28947  your a/c xxxxxxx4289 is debited through atm by...    交易流水＿转账
# sent_29301  your a/c xxxx8575 debited rs.149000.00 on 19-0...    交易流水＿转账
# sent_29320  returned, chq:940102 for rs.15431.00 fvg capit...  sms_other
# sent_29519  your a/c ...162 in credited inr 21000.00 on 21...    交易流水＿转账
# sent_29635  dear customer,your loan a/c 1441***121 with io...  贷后提醒＿逾期催收
# sent_2990   dear customer, cheque 995044 for inr 43000 iss...  账号异常＿扣款失败
# sent_3289   dear customer,your account xx7410 has been cre...    交易流水＿转账
# sent_3668   bank is replacing your existing magstripe debi...  账号异常＿卡号冻结
# sent_3953   inr 5,400.00 credited to your a/c no xxxxxxx84...    交易流水＿转账
# sent_458    your indusind bank a/c no.200***439985 has bee...    交易流水＿转账
# sent_4768   your a/c no. xxxxxxxx862071 is credited by rs....    交易流水＿转账
# sent_4936   dear customer - your neft payment with utr bdb...    交易流水＿转账
# sent_4976   your a/c no. xxxx914167 is credited rs.3000.00...    交易流水＿转账
# sent_5056   transaction of rs 5000 has been made on kotak ...    交易流水＿转账
# sent_5454   inr 1.00 is credited to your a/c xxxx9121 on 1...    交易流水＿转账
# sent_5692   you have successfully done a vodafone prepaid ...    交易流水＿转账
# sent_6138   hello! you have received refund of transaction...    交易流水＿转账
# sent_6561   thanks for applying loan through hdb. your loa...  贷前申请＿申请交互
# sent_6690   dear customer, emi of rs 3594 of your cd loan ...  贷后提醒＿到期提醒
# sent_8284   your a/c no. xxxxxxxxxxx1608 is debited for rs...    交易流水＿转账
# sent_8327   your fund transfer for rs. 6500 on 21-09-18 co...  账号异常＿扣款失败
# sent_9054   dear customer, your username avxxxxxh9553 is l...  账号异常＿卡号冻结
# sent_9766   thanks for rs.4,500.00 received via neft for c...    交易流水＿转账
# sent_9927   your debit card 5497xxxxxxxx0600 has been used...    交易流水＿转账
#
# [100 rows x 2 columns]

# %%
df3_te
# Out:
#                                                           sms        cls
# sent_id
# sent_10460  thank you for payment of inr.6000.00 on your c...    交易流水＿转账
# sent_10998  dear customer,your transaction at atm 1cn04401...  账号异常＿余额不足
# sent_11310  your a/c no. xxxxxxx7494 is debited for inr 2,...    交易流水＿转账
# sent_1142   your a/c xxxxxxx5273 has been debited with inr...    交易流水＿转账
# sent_11776  your a/c no. ***********5885 is credited for r...    交易流水＿转账
# sent_1184   inr 9,400.00 credited to your a/c no xxxxxxx49...    交易流水＿转账
# sent_12118  dear boi customer, a/c xxxxxxxxxxx6116 charged...    交易流水＿转账
# sent_12381  rs.30 has been debited from your kotak account...    交易流水＿转账
# sent_1239   a/c nn4214 debited for inr 24; atm wdl. a/c ba...    交易流水＿转账
# sent_12633  dear customer, refund of rs .82 from hpcl 0.75...    交易流水＿转账
# sent_13206  your a/c no. xxxxxxxx1061 is debited for rs.3....    交易流水＿转账
# sent_13481  dear customer, payment received for amount of ...    交易流水＿转账
# sent_13846  your profile password for username xxxaan has ...  账号异常＿卡号冻结
# sent_13944  bill payment for ketaki has been made successf...    交易流水＿转账
# sent_14307  your a/c no. xxxxxx1711 is credited for rs.20....    交易流水＿转账
# sent_14432  pos tran of rs.1522.00 is done on card xx0742 ...    交易流水＿转账
# sent_1457   idbi bk a/c. nnnnn64164 credited rs 8000.00 tw...    交易流水＿转账
# sent_14673  your a/c no. xxxx651 is debited with rs 199.00...    交易流水＿转账
# sent_15051  a/c 3xxxxx6226 debited by rs. 1,500 total bal:...    交易流水＿转账
# sent_15753  your a/c no. xxxxxxxxxxx8248 is debited for rs...    交易流水＿转账
# sent_16041  hello! your a/c no 60313147 has been credited ...    交易流水＿转账
# sent_1655   dear customer, your a/c no. xxxxxxxx9939 is de...    交易流水＿转账
# sent_16565  your debit card ending 1471 has been blocked. ...  账号异常＿卡号冻结
# sent_16602  your fund transfer request for rs. 1000.0 on 2...  账号异常＿扣款失败
# sent_1699   you have initiated a txn of inr 415.68 at irct...    交易流水＿转账
# sent_17046  your ac xxxxx774561 debited inr 60,000.00 on 3...    交易流水＿转账
# sent_17090  hold for inr 10,000.00 created in your ac xxxx...    交易流水＿转账
# sent_17308  dear customer, hold has been placed on your ac...  账号异常＿卡号冻结
# sent_17326  loan of rs. 75000.00 disbursed from loan a/c n...  贷后提醒＿到期提醒
# sent_17349  tds of inr 332.00 deducted for interest paid o...    交易流水＿转账
# ...                                                       ...        ...
# sent_28001  dear customer, a/c xxx1662 charged rs.600 for ...  sms_other
# sent_28068  ur transaction on hdfc bank credit card ending...    交易流水＿转账
# sent_28375  update: inr 25,000.00 debited from a/c xx0830 ...    交易流水＿转账
# sent_28392  dear customer.thank you for your recent paymen...  贷后提醒＿到期提醒
# sent_28495  dear customer,we regret to note that payments ...   信用卡＿还款提醒
# sent_2888   dear customer, total amount due on credit card...   信用卡＿还款提醒
# sent_28947  your a/c xxxxxxx4289 is debited through atm by...    交易流水＿转账
# sent_29301  your a/c xxxx8575 debited rs.149000.00 on 19-0...    交易流水＿转账
# sent_29320  returned, chq:940102 for rs.15431.00 fvg capit...  sms_other
# sent_29519  your a/c ...162 in credited inr 21000.00 on 21...    交易流水＿转账
# sent_29635  dear customer,your loan a/c 1441***121 with io...  贷后提醒＿逾期催收
# sent_2990   dear customer, cheque 995044 for inr 43000 iss...  账号异常＿扣款失败
# sent_3289   dear customer,your account xx7410 has been cre...    交易流水＿转账
# sent_3668   bank is replacing your existing magstripe debi...  账号异常＿卡号冻结
# sent_3953   inr 5,400.00 credited to your a/c no xxxxxxx84...    交易流水＿转账
# sent_458    your indusind bank a/c no.200***439985 has bee...    交易流水＿转账
# sent_4768   your a/c no. xxxxxxxx862071 is credited by rs....    交易流水＿转账
# sent_4936   dear customer - your neft payment with utr bdb...    交易流水＿转账
# sent_4976   your a/c no. xxxx914167 is credited rs.3000.00...    交易流水＿转账
# sent_5056   transaction of rs 5000 has been made on kotak ...    交易流水＿转账
# sent_5454   inr 1.00 is credited to your a/c xxxx9121 on 1...    交易流水＿转账
# sent_5692   you have successfully done a vodafone prepaid ...    交易流水＿转账
# sent_6138   hello! you have received refund of transaction...    交易流水＿转账
# sent_6561   thanks for applying loan through hdb. your loa...  贷前申请＿申请交互
# sent_6690   dear customer, emi of rs 3594 of your cd loan ...  贷后提醒＿到期提醒
# sent_8284   your a/c no. xxxxxxxxxxx1608 is debited for rs...    交易流水＿转账
# sent_8327   your fund transfer for rs. 6500 on 21-09-18 co...  账号异常＿扣款失败
# sent_9054   dear customer, your username avxxxxxh9553 is l...  账号异常＿卡号冻结
# sent_9766   thanks for rs.4,500.00 received via neft for c...    交易流水＿转账
# sent_9927   your debit card 5497xxxxxxxx0600 has been used...    交易流水＿转账
#
# [100 rows x 2 columns]

# %%
text = df3_te.sms.tolist()

# %%
tr4w = TextRank4Keyword()

tr4w.analyze(text=text, lower=True, window=2)  # py2中text必须是utf8编码的str或者unicode对象，py3中必须是utf8编码的bytes或者str对象

print( '关键词：' )
for item in tr4w.get_keywords(20, word_min_len=1):
    print(item.word, item.weight)

print()
print( '关键短语：' )
for phrase in tr4w.get_keyphrases(keywords_num=20, min_occur_num= 2):
    print(phrase)

tr4s = TextRank4Sentence()
tr4s.analyze(text=text, lower=True, source = 'all_filters')

print()
print( '摘要：' )
for item in tr4s.get_key_sentences(num=3):
    print(item.index, item.weight, item.sentence)  # index是语句在文本中位置，weight是权重
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-6a788a492f11> in <module>
#       1 tr4w = TextRank4Keyword()
#       2
# ----> 3 tr4w.analyze(text=text, lower=True, window=2)  # py2中text必须是utf8编码的str或者unicode对象，py3中必须是utf8编码的bytes或者str对象
#       4
#       5 print( '关键词：' )
#
# ~/test1/lib/python3.5/site-packages/textrank4zh/TextRank4Keyword.py in analyze(self, text, window, lower, vertex_source, edge_source, pagerank_config)
#      66         self.graph = None
#      67
# ---> 68         result = self.seg.segment(text=text, lower=lower)
#      69         self.sentences = result.sentences
#      70         self.words_no_filter = result.words_no_filter
#
# ~/test1/lib/python3.5/site-packages/textrank4zh/Segmentation.py in segment(self, text, lower)
#     117
#     118     def segment(self, text, lower = False):
# --> 119         text = util.as_text(text)
#     120         sentences = self.ss.segment(text)
#     121         words_no_filter = self.ws.segment_sentences(sentences=sentences,
#
# ~/test1/lib/python3.5/site-packages/textrank4zh/util.py in as_text(v)
#      38             return v
#      39         else:
# ---> 40             raise ValueError('Unknown type %r' % type(v))
#      41
#      42     def is_text(v):
#
# ValueError: Unknown type <class 'list'>

# %%
def result(G, output, label_idx, idx2label):
    SF = nn.Softmax(dim=-1)
    score, pred = SF(output).max(dim=-1)
    sms = [G.node[i]['text'] for i in label_idx]
    df = pd.DataFrame()
    df['sms']= sms
    df['score']=score.data
    df['pred']=[idx2label[i] for i in pred.numpy()]
    df['label']=[g4.node[i]['label'] for i in label_idx]
    return df

def get_clf_prediction(model, X_word, X_char, y):
    print('X shape:{}, y_shape:{}'.format(len(X_word), len(y)))
    y_pred = model.predict([X_word,
                            np.array(X_char).reshape((len(X_char),
                                                         max_len, max_len_char))])
    pred = [idx2label[i] for i in np.argmax(y_pred,axis=-1)]
    true = [idx2label[i] for i in y]
    return true, pred

def get_pr(Res, cls):
    #某类 正确识别数量/该类 总识别数量
    tmp  = Res[Res.true == cls]
    a = sum(tmp.true.values == tmp.pred.values)
    b = Res[Res.pred == cls].shape[0]
    pr = a/b
    return pr

def get_rc(Res, cls):
    #某类 正确识别数量/该类 总数量
    tmp  = Res[Res.true == cls]
    support = tmp.shape[0]
    a = sum(tmp.true.values == tmp.pred.values)
    b = Res[Res.true == cls].shape[0]
    rc = a/b
    return rc,support

def get_f1(pr, rc):
    # f1 = (2*pr*rc)/(pr+rc)
    f1 = (2*pr*rc)/(pr+rc)
    return f1

def evaluate(Res, cls):
    pr = get_pr(Res, cls)
    rc, support = get_rc(Res, cls)
    f1 = get_f1(pr, rc)
    return [cls, pr, rc, f1, support]

def Final_evalu(z):
    Res = pd.DataFrame(columns=['true', 'pred'])
    true, pred = z.label.tolist(), z.pred.tolist()
    Res['true'] = true
    Res['pred'] = pred
    entitys = Res.true.unique()
    records = []
    for i in entitys:
        tmp = evaluate(Res, i)
        records.append(tmp)
    record = pd.DataFrame.from_records(records)
    record.columns =['cls','精确率','召回率', 'F1', 'support']
    record = record.set_index('cls')
    record = record.sort_index()   
    return record

# %%
import networkx as nx
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer,TfidfVectorizer
from numpy import dot
from numpy.linalg import norm
from sklearn.metrics.pairwise import cosine_similarity
import torch
import torch.nn as nn
import copy
# from graphviz import Digraph
from torch.nn import init
from torch.autograd import Variable
import torch.nn.functional as F
import time
import random
from sklearn.metrics import f1_score
# from collections import defaultdict
# from ClfTemplates import get_all_template_path, sample_template, sample_template_path
# from ClfUse import showClfResult, get_samples, labeledDataFromJson
# from Ner_model import get_X_Y, lstm_crf, predict, preprocess
# from Ner_data_make import create_fake_label, fake2real
from keras.preprocessing.sequence import pad_sequences

from keras.models import Model, Input, Sequential
from keras.layers import LSTM, Embedding, SpatialDropout1D,concatenate, Dense, TimeDistributed, Dropout, Bidirectional
from keras_contrib.layers import CRF
from keras_contrib.losses import crf_loss
from keras.utils import to_categorical
import keras
from collections import Iterable 
import pandas as pd
import numpy as np
import random
import re
import warnings
warnings.filterwarnings("ignore")


# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd
import random

def gen_new(ori_str):
    return ''.join([str(random.randint(0,9)) if i.isdigit() else i for i in list(ori_str)])

def create_fake_label(DF, fake_times):
    DF2 = DF.copy()
    for i in range(fake_times):
        col = DF2.apply(lambda x: gen_new(x.token) if x.lable!='other' else x.token, axis=1)
        DF2['new_tokens_{}'.format(i)] = col
    return DF2

def generate_sent_id(sent_id_list, origin_sent_id):
    dic = {}
    for k in origin_sent_id:
        tmp = 'send_id_' + str(sent_id_list[-1])
        sent_id_list.pop()
        dic.setdefault(k, tmp)
    return sent_id_list, dic

def fake2real(df, fake_times):
    '''label 写错了，将错就错'''
    lis = []
    sent_id_list = list(range(len(df.sent_id.unique()) * fake_times))
    origin_sent_id = df.sent_id.unique()
    for i in range(fake_times):
        tmp_df = df[['new_tokens_{}'.format(i), 'lable', 'sent_id']]
        tmp_df.columns = ['token', 'lable', 'sent_id']
        sent_id_list, dic = generate_sent_id(sent_id_list, origin_sent_id)
        tmp_df.sent_id = tmp_df.sent_id.map(dic)
        lis.append(tmp_df)
    return pd.concat(lis)

def fake2real_v2(df, fake_times):
    lis = []
    sent_id_list = list(range(len(df.sent_id.unique()) * fake_times))
    origin_sent_id = df.sent_id.unique()
    for i in range(fake_times):
        tmp_df = df[['new_tokens_{}'.format(i), 'sent_id', 'cls']]
        tmp_df.columns = ['token', 'sent_id', 'cls']
        sent_id_list, dic = generate_sent_id(sent_id_list, origin_sent_id)
        tmp_df.sent_id = tmp_df.sent_id.map(dic)
        lis.append(tmp_df)
    return pd.concat(lis)

# %% [markdown]
# ### 1. sms 文件

# %%
import pickle
import os
from IPython.display import display
import itertools
# /home/qibo/sms_nlp
res_root = '/home/qibo/sms_nlp/annotation_results/round_2_results_bank/'
# res_root = '/home/qibo/work_notebooks/sms_nlp/annotation_results/round_2_results_loan/'
ALL = []
for idx,fn in enumerate(os.listdir(res_root)):
    print(fn)
    despatcher = fn.split('.')[0]
    print(despatcher)
    with open(os.path.join(res_root, fn), 'rb') as fin:
        tasks = pickle.load(fin)

    for key, group in itertools.groupby(tasks, key=lambda x:x.output[0]):
#         print(list(group)[-2].output)
#         print('##############################')
#         print(list(group)[-1].output)
        regex_id = key
        to_display = None
        sms_type = None
        fields = []
        field_types = []
        for t in list(group):
            output = t.output
            val = t.value
            regex_id = output[0]
            group_id = output[1]
            gened_regex = output[2]
            box_markups = output[3]
            if group_id == 0:
                sms_type = val
                if sms_type:
                    print(regex_id, gened_regex)
                    print('短信类型: ', sms_type)
                to_display = box_markups[0][0]
                text = box_markups[0][0].text
#                 print('text :', text)
                spans = box_markups[0][0].spans
                for s in spans:
                    fields.append(text[s.start : s.stop])
            else:
                field_types.append(val)
        print(field_types)
        if None not in field_types:
            tem = {}
            for i , j in zip(fields, field_types):
                tem[i] = j
            new_text = 'Reg_id_' + str(regex_id) + ' ' + text
#             print(cluster_id)
            ALL.append([text, fields ,field_types, tem, sms_type])
        print('------------------------------------------------------')
# Out:
# indusb.pkl
# indusb
# 3764 ^Dear Customer Txn on IndusInd Bank Credit Card no .* for INR .* on .* at .* is .* call 18602677777 for query\.Click on http\:\/\/bit\.ly\/2B8nSNl to update your Aadhaar Number\, ignore if already done\.$
# 短信类型:  交易流水＿转账
# ['银行卡号＿自己', '金额＿转出', '日期＿交易时间', '机构＿交易平台', 'other']
# ------------------------------------------------------
# 3765 ^Your IndusInd Bank A\/C .* has been debited for .* towards your Debit Card purchase\.The available Balance is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '金额＿余额']
# ------------------------------------------------------
# 3766 ^Your a\/c no\. .* is credited by .* on .* by a\/c linked to mobile .* \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 3767 ^Your IndusInd Bank A\/C .* has been debited for .* towards an ATM Cash Withdrawal Transaction\. Available Balance is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '金额＿余额']
# ------------------------------------------------------
# 3768 ^Your a\/c no\. .* is debited for .* on .* and a\/c .* credited \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 3772 ^Dear Customer\, Your account no .* has been Credited for INR .* towards .* Your combine balance is INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', 'other', '金额＿余额']
# ------------------------------------------------------
# 3773 ^Dear Customer\, thank you for your .* Payment of INR .* towards your IndusInd Bank Credit Card .* Your payment is credited to your Credit Card a\/c on .*$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', '银行卡号＿自己', '日期＿交易时间']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 3776 ^Dear Customer\, statement for your IndusInd Bank Credit Card \# .* dated .* due .* will be delivered shortly\. Total Amount Due is INR .* and Minimum Amount Due is INR .* keep track of your Credit Card outstanding and view statements\, download the IndusMobile App now\: http\:\/\/goo\.gl\/zQM2Yl$
# 短信类型:  信用卡＿还款提醒
# ['银行卡号＿自己', '日期＿还款日期', 'other', '金额＿应还金额', '金额＿最小应还金额']
# ------------------------------------------------------
# 3777 ^Your curr loan EMI .* for .* due on .* Pls pay or ensure suff bal on presentation\. Ignore if paid already\. For Queries call .* mail us in reach4loan\@indusind\.com$
# 短信类型:  贷后提醒＿逾期催收
# ['金额＿应还金额', 'other', '日期＿还款日期', 'other']
# ------------------------------------------------------
# 3778 ^Your a\/c no\. .* is credited for Rs\. .* on .* and debited from .* \(UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 3781 ^Dear Customer\, as per the last statement generated for your IndusInd Bank Credit Card ending \# .* total \& minimum amounts due are .* \& .* respectively\. We request you to make the payment by the due date ie .* You can use any of our convenient online payment options\:http\:\/\/bit\.ly\/2B2fkmj or download the all new IndusMobile App to make your Credit Card payment\: http\:\/\/goo\.gl\/zQM2Yl \. Please ignore if paid already\.$
# 短信类型:  信用卡＿逾期警告
# ['银行卡号＿自己', '金额＿应还金额', '金额＿最小应还金额', '日期＿还款日期']
# ------------------------------------------------------
# 3783 ^Dear Customer\, Your account no .* has been Debited for INR .* towards .* Your .* balance is INR .* Get mobile banking\@ https\:\/\/tinyurl\.com\/y94zzu8k$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', 'other', 'other', '金额＿余额']
# ------------------------------------------------------
# 3784 ^Ur curr loan EMI Rs\. .* for .* due on .* Pls pay or ensure suff bal on or before presentation in ur bank acc\. Ignore if paid already\. Qrs call 18001023333 mail us reach4loan\@indusind\.com\.$
# 短信类型:  贷后提醒＿到期提醒
# ['金额＿应还金额', 'other', '日期＿还款日期']
# ------------------------------------------------------
# 3787 ^Dear Customer\, the payment on your IndusInd Bank Credit Card \# .* is overdue\. The minimum amount due is INR .* We request you to make the payment immediately using any of our convenient online payment options\: http\:\/\/bit\.ly\/2B2fkmj or download the all new IndusMobile App to make your Credit Card payment\: http\:\/\/goo\.gl\/zQM2Yl Please ignore if paid already or if you have provided a standing instruction to debit your account\.$
# 短信类型:  信用卡＿逾期警告
# ['银行卡号＿自己', '金额＿应还金额']
# ------------------------------------------------------
# 3789 ^Your IndusInd Bank A\/C .* has been credited by .* towards cash deposit\. The available Balance is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '金额＿余额']
# ------------------------------------------------------
# 3790 ^Your IndusInd Bank A\/C No\. .* has been debited for Rs\. .* towards INDUSMOBILE\-RECHARGE on .* The available balance is Rs\. .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 3791 ^Dear Customer\, your Savings Account A\/C .* has been credited with INR .* towards Interest Credit for the quarter ending .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', 'other']
# ------------------------------------------------------
# 3792 ^Dear Customer\, Txn on IndusInd Bank Credit Card .* for INR .* on .* at .* is Approved\. Pls call 18602677777 for query\.$
# 短信类型:  交易流水＿转账
# ['银行卡号＿自己', '金额＿转出', '日期＿交易时间', '机构＿交易平台']
# ------------------------------------------------------
# 3801 ^Dear Customer\, the .* Statement for your IndusInd Bank credit card no\. .* is delivered to your mailing address\. The total and minimum amount due are INR .* and INR .* respectively\. To view or request for your Credit Card e\-Statement\, login\/download the IndusMobile App\: http\:\/\/goo\.gl\/zQM2Yl$
# 短信类型:  信用卡＿还款提醒
# ['日期＿还款日期', '银行卡号＿自己', '金额＿应还金额', '金额＿最小应还金额']
# ------------------------------------------------------
# 3805 ^Bal of INR .* on .* AM in A\/C .* will earn 6\% pa on bal above 10cr\,5\.5\% pa on balance above 1cr\,5\% pa above 10lac\,4\%pa upto 10lac\.For Balance details call 18002741000\. Get mobile banking\@ .*$
# 短信类型:  交易流水＿余额
# ['金额＿余额', '日期＿交易时间', '账户账号＿自己', 'other']
# ------------------------------------------------------
# 3818 ^Dear Customer\, In your account .* the amount of Rs\. .* which was hold marked is now released\. Your available combined balance is .* Please contact to branch \\ Contact Center for any further queries\.$
# 短信类型:  sms_other
# [None, None, None]
# ------------------------------------------------------
# 3819 ^Sorry\! The balance available in your IndusInd Bank A\/C .* is not sufficient to process your transaction\. Your balance is Rs\. .*$
# 短信类型:  账号异常＿余额不足
# ['账户账号＿自己', '金额＿余额']
# ------------------------------------------------------
# 3822 ^Dear Cust\, Thanks for your Cash payment of .* dtd .* towards your Loan acct vide rpt\# .* For queries call 18001023333 mail us in reach4loan\@indusind\.com$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 3829 ^IndusInd bank A\/c .* has been credited for .* towards a NEFT Credit from .* with Transaction Reference Number .* Available balance is .* Get mobile banking\@ bit\.ly\/IndusM$
# 短信类型:  账户账号＿自己
# ['金额＿转入', 'other', 'other', 'other', '金额＿余额']
# ------------------------------------------------------
# 3832 ^Your Bank A\/C .* has been debited for INR .* towards IndusMobile .* Transfer on .* Avl Bal is INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', 'other', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# 3842 ^Your fund transfer for Rs\. .* on .* is declined as the beneficiary Account no or IFS Code is invalid \(IMPS Ref no\. .*$
# 短信类型:  账号异常＿扣款失败
# ['金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 3845 ^The balance in your a\/c .* has been below the min\. balance requirement .* Please maintain .* balance in .* to avoid .*$
# 短信类型:  账号异常＿余额不足
# ['账户账号＿自己', '日期＿交易时间', 'other', 'other', 'other']
# ------------------------------------------------------
# 3847 ^Your one time password for PIN Generation on IVR is .* \.The password would expire by .* If you have not requested this please contact 18605005004 urgently\. Please do not share the OTP with anyone for security reasons\.$
# 短信类型:  sms_other
# ['other', 'other']
# ------------------------------------------------------
# 3849 ^IndusInd Bank A\/C .* has been debited for .* towards IndusMobile NEFT transfer with UTR Number .* Available balance is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', 'other', '金额＿余额']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 3857 ^The balance in your a\/c .* has been below the min\. balance requirement in .* Please fund the a\/c to maintain balance in .* to avoid .*$
# 短信类型:  账号异常＿余额不足
# ['账户账号＿自己', 'other', '日期＿交易时间', 'other']
# ------------------------------------------------------
# ['other', '账户账号＿自己', '金额＿转出', None, None]
# ------------------------------------------------------
# 3871 ^Cheque No\. .* issued by you for .* in A\/C .* is returned\.Transfer funds online with ease\. Get mobile banking\@ .*$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', '账户账号＿自己', 'other']
# ------------------------------------------------------
# 3873 ^Thanks for availing 2WHEELER Loan .* from IBL\. Pls note the same for future correspondence\. EMI Due Date \: .* of every month\, EMI .* For queries pls call 18001023333 mail us in reach4loan\@indusind\.com$
# 短信类型:  贷前申请＿申请交互
# ['other', 'other', '金额＿应还金额']
# ------------------------------------------------------
# 3879 ^Your Bank A\/C .* has been Dr for INR .* towards IndusMobile NEFT transfer with UTR .* Avl Bal is INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', 'other', '金额＿余额']
# ------------------------------------------------------
# 3884 ^Dear Customer\, Your NEFT Transaction with ref\. number .* for Rs .* has been credited to the beneficiary\. Thank You\. Get mobile banking\@ .*$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转入', 'other']
# ------------------------------------------------------
# 3888 ^Cheque No\. .* for .* issued from your Indusind Bank A\/C .* has been dishonoured\.Transfer funds with IndusMobile\. Get mobile banking\@ .*$
# 短信类型:  账号异常＿扣款失败
# ['other', '金额＿转出', '账户账号＿自己', 'other']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 3892 ^Your IndusInd Bank A\/C .* has been debited for .* towards .* Recharge via IndusMobile on .* The available Balance is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', 'other', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# ['other', None, 'other', 'other', 'other', 'other', 'other']
# ------------------------------------------------------
# 3896 ^Your fund transfer for Rs\. .* on .* is declined\. Please refer to the beneficiary \(IMPS Ref no\. .*$
# 短信类型:  账号异常＿扣款失败
# ['金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 3907 ^Bal of INR .* on .* AM in A\/C .* will earn 6\% pa on bal above 10cr\,5\.5\% pa on balance above 1cr\,5\% pa above 10lac\,4\%pa upto 10lac\.For .* details call .*$
# 短信类型:  交易流水＿余额
# ['金额＿余额', '日期＿交易时间', '账户账号＿自己', 'other', 'other']
# ------------------------------------------------------
# ['other', 'other', 'other']
# ------------------------------------------------------
# 3909 ^The balance in your a\/c .* has been below the min\. balance requirement .* Please maintain balance in .* to avoid charges\.$
# 短信类型:  账号异常＿余额不足
# ['账户账号＿自己', 'other', '日期＿交易时间']
# ------------------------------------------------------
# sbipsg.pkl
# sbipsg
# 2084 ^INR .* credited to your A\/c No .* on .* through NEFT with UTR .* by .*$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 2086 ^Your A\/c .* has been debited with INR .* on .* towards NEFT with UTR .* sent to .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 2087 ^Your NEFT of Rs .* with UTR .* DTD .* credited to Beneficiary AC NO\. .* at .* on .* at .*$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other', '日期＿交易时间', '账户账号＿他人', 'other', 'other', 'other']
# ------------------------------------------------------
# 2088 ^INR .* credited to your A\/c No .* on .* through NEFT with UTR .* by .* PVT LTD$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 2106 ^As per your request received at Contact Centre\,Card No ending with .* is Blocked\.Ticket .*$
# 短信类型:  账号异常＿卡号冻结
# ['银行卡号＿自己', 'other']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# idbibk.pkl
# idbibk
# [None, None, None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 882 ^Your a\/c no\. .* is debited for .* on .* and credited to a\/c no\. .* \(UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 884 ^A\/c .* debited for INR .* ATM WDL\. A\/c Bal INR .* \(incl\. of uncleared chqs\) as of .* Call 1800226999 if card not used by you\.$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 885 ^A\/c .* credited for .* through .* Banking\. A\/c Bal .* \(incl\. of uncleared chqs\) as of .* hrs\.$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', 'other', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 888 ^Dear Customer\, Your a\/c no\. .* is credited by .* on .* by a\/c linked to mobile .* \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 890 ^A\/c .* debited for Rs .* thru Net\/Mob Bkg\. A\/c Bal Rs .* \(incl\. of uncleared chqs\) as of .* If not used by you\, call 18002001947$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 892 ^Dear Customer\, Your a\/c no\. .* is debited for .* on .* and a\/c .* credited \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 898 ^A\/c .* debited for Rs .* thru .* Bkg\. A\/c Bal Rs .* \(incl\. of uncleared chqs\) as of .* If not used by you\, call 18002001947$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', 'other', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 900 ^Your IDBI Bk A\/c .* credited by Rs .* for Cash Deposit\. A\/c Bal\(sub to chq realisation\) Rs .* as of .* hrs\.$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 901 ^Dear Customer\, The Available Balance in account .* is INR .* as of .* hrs$
# 短信类型:  交易流水＿余额
# ['账户账号＿自己', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 902 ^The Monthly Avg bal\(MAB\) in your .* in .* was Rs\. .* and the deficit is Rs .* Restore MAB by .* to avoid penal charges\.$
# 短信类型:  信用卡＿还款提醒
# ['账户账号＿自己', 'other', 'other', '金额＿应还金额', '日期＿还款日期']
# ------------------------------------------------------
# 903 ^IDBI Bk A\/c\. .* credited Rs .* twds .* A\/c Bal Rs .* on .* hrs\.\(subject to chq realisation\)$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', 'other', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 906 ^Dear Customer\, Amount of .* towards your unsuccessful .* transaction has been reversed\.$
# 短信类型:  账号异常＿扣款失败
# ['金额＿转出', 'other']
# ------------------------------------------------------
# 913 ^Your IDBI Bk A\/c\. .* debited Rs .* on .* Details\: .* A\/c Bal Rs .* as of .* hrs\.$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', '金额＿余额', 'other']
# ------------------------------------------------------
# 917 ^Rs .* has been spent on your Credit Card ending .* on .* at .* AVL bal .* call customer care 18004257600 if not used\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '银行卡号＿自己', '日期＿交易时间', '机构＿交易平台', '金额＿余额']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None, None, None, None]
# ------------------------------------------------------
# 921 ^Your chq .* for Rs\. .* from .* is Returned with Reason\-FUNDS INSUFFICIENT\.$
# 短信类型:  账号异常＿余额不足
# ['other', '金额＿转出', '账户账号＿自己']
# ------------------------------------------------------
# 925 ^Your a\/c no\. .* is credited for .* on .* for reversal of transaction \(UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 948 ^Penalty of Rs .* applied on your saving account .* for shortfall of MAB in .* having not restored MAB in .* after giving one month notice\.$
# 短信类型:  账号异常＿余额不足
# ['金额＿逾期罚金', '账户账号＿自己', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 952 ^Your OTP for applying loan is .*$
# 短信类型:  贷前申请＿申请交互
# ['other']
# ------------------------------------------------------
# 959 ^Penal chgs of .* applied to Current A\/c .* Non\-maintenance of MAB\. MAB maintained for .* is .* as against the stipulated of .*$
# 短信类型:  账号异常＿余额不足
# ['金额＿逾期罚金', '账户账号＿自己', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 961 ^Mini statement for Credit Card .* Total Due Rs\. .* Minimum Due Rs\. .* Payment Due Date\: .* Refer statement for more details$
# 短信类型:  信用卡＿还款提醒
# ['银行卡号＿自己', '金额＿应还金额', '金额＿最小应还金额', '日期＿还款日期']
# ------------------------------------------------------
# [None, None]
# ------------------------------------------------------
# 964 ^Your debit mandate for .* for Max .* is registered with us upto .* in your A\/c .* Customer Care for more details\.$
# 短信类型:  sms_other
# ['other', 'other', 'other', None]
# ------------------------------------------------------
# axicicib.pkl
# axicicib
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', None]
# ------------------------------------------------------
# 9351 ^Dear Customer\, Your a\/c no\. .* is debited for .* on .* and a\/c .* credited \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 9352 ^Dear Customer\, Your a\/c no\. .* is credited by .* on .* by a\/c linked to mobile .* \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 9353 ^You have initiated a txn of INR .* at .* on ICICI Bank Card .* OTP is .* DONT SHARE WITH ANYONE\. BANK NEVER CALLS TO VERIFY OTP\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '机构＿交易平台', '银行卡号＿自己', 'other']
# ------------------------------------------------------
# 9354 ^Dear Customer\, your Account .* has been credited with INR .* on .* Info\: .* The Available Balance is INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 9356 ^Dear Customer\, acct .* has been debited for .* on .* towards linked .* UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '机构＿交易平台', 'other']
# ------------------------------------------------------
# ['账户账号＿自己', '金额＿转出', None, None]
# ------------------------------------------------------
# 9358 ^Dear Customer\, acct .* is credited with .* on .* from .* UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 9359 ^Dear Customer\, txn of INR .* using Credit Card .* done at .* on .* Avbl Cr lmt\:INR .* For dispute\,call 04033667777\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '银行卡号＿自己', '机构＿交易平台', '日期＿交易时间', '金额＿信用额度']
# ------------------------------------------------------
# 9360 ^You have initiated a txn of INR .* at .* on ICICI Bank Card .* OTP is .* DONT SHARE IT WITH ANYONE\. BANK NEVER CALLS TO VERIFY OTP\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '机构＿交易平台', '银行卡号＿自己', 'other']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 9363 ^Dear Customer\, you have a collect request for .* from vpa .* Login to your mobile application to authorise the transaction\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '机构＿交易平台']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 9365 ^Dear Customer\, stmt for Credit Card .* has been sent to .* Total amt of Rs\. .* or Min\. amt of Rs\. .* is due by .*$
# 短信类型:  信用卡＿还款提醒
# ['银行卡号＿自己', 'other', '金额＿应还金额', '金额＿最小应还金额', '日期＿还款日期']
# ------------------------------------------------------
# 9368 ^Cash deposit transaction of Rs\. .* for Account .* has been completed on .* vide transaction reference .*$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '账户账号＿自己', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 9373 ^Dear Customer\, Total Amount of INR .* and Minimum Amount of INR .* is due by .* on your Credit Card .* Please ignore if already paid\.$
# 短信类型:  信用卡＿还款提醒
# ['金额＿应还金额', '金额＿最小应还金额', '日期＿还款日期', '银行卡号＿自己']
# ------------------------------------------------------
# 9374 ^Dear Customer\, the Available Balance for your ICICI Bank Account .* is INR .* as on .*$
# 短信类型:  交易流水＿余额
# ['账户账号＿自己', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 9375 ^Dear Customer\, acct .* has been debited for .* on .* and Acct .* is credited\. UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 9376 ^Dear Customer\,ECS transaction of Rs\. .* towards .* from Account .* has been returned due to reason \- .* on .*$
# 短信类型:  账号异常＿余额不足
# ['金额＿转出', '机构＿交易平台', '账户账号＿自己', 'other', '日期＿交易时间']
# ------------------------------------------------------
# 9377 ^Dear Customer\, You have a collect request for .* from .* To authorise\, login to iMobile app or click bit\.ly\/UPI\-Collectrequest$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '机构＿交易平台']
# ------------------------------------------------------
# 9378 ^Dear Customer\,Your transaction of INR .* on Credit Card .* declined due to insufficient limit\.Limit available\: INR .*$
# 短信类型:  账号异常＿扣款失败
# ['金额＿转出', '银行卡号＿自己', '金额＿信用额度']
# ------------------------------------------------------
# 9380 ^Dear Customer\, .* of Rs\. .* to Account .* has been initiated through INSTA Banking\. Please quote Reference .* at the counter\. You will get another SMS confirming the completion of transaction\. Request for a hard copy receipt\, if you do not receive the confirmation SMS\.$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转入', 'other', 'other']
# ------------------------------------------------------
# 9385 ^Dear Customer\,EMI of Rs\. .* towards ICICI Bank Loan Account .* is due on .*$
# 短信类型:  贷后提醒＿到期提醒
# ['金额＿应还金额', '账号＿借款编号', '日期＿还款日期']
# ------------------------------------------------------
# 9386 ^Dear Customer\, your Account .* has been credited with salary of INR .* on .* Info\: .* The Available Balance is INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿薪资', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# 9389 ^Dear Customer\, Refund of INR .* from .* has been credited to your Credit Card .* on .* For details\, please call our Customer Care\.$
# 短信类型:  交易流水＿转账
# ['金额＿转入', 'other', '银行卡号＿自己', '日期＿交易时间']
# ------------------------------------------------------
# 9393 ^Payment overdue on your Credit Card .* is affecting your credit history with CIBIL\. This may prevent you from getting a loan or a credit card from any bank in future\. To avoid further damage to your credit .* pay the total amt due .* or the min amt .* imm\.Pl ignore if .*$
# 短信类型:  信用卡＿还款提醒
# ['银行卡号＿自己', 'other', '金额＿应还金额', '金额＿最小应还金额', 'other']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 9402 ^Dear Customer\, Your fund transfer request for .* on .* could not be processed\. Please try later\. \(IMPS Ref no\. .*$
# 短信类型:  账号异常＿扣款失败
# ['金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# [None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 9408 ^Dear Customer\, you have made a payment of Rs\. .* to ARTHASHASTRA FINTECH PRIVATE LIMITED vide eazypay reference ID .*$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other']
# ------------------------------------------------------
# 9409 ^Dear Customer\, .* Amount Due on Credit Card .* is INR .* Amt will be debited from your bank account on or before .* Pls ignore if paid\.$
# 短信类型:  信用卡＿还款提醒
# ['other', '银行卡号＿自己', '金额＿应还金额', '日期＿还款日期']
# ------------------------------------------------------
# 9411 ^You have initiated a txn of INR .* at .* on ICICI Bank Card 4005\. OTP is .* DONT SHARE IT WITH ANYONE\. BANK NEVER CALLS TO VERIFY OTP\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '机构＿交易平台', 'other']
# ------------------------------------------------------
# 9412 ^Dispatched\: Dear Customer\, Credit Card Statement for your Account .* has been sent by .* AWB .* on .* Track status at bit\.ly\/2prKKli\.$
# 短信类型:  sms_other
# ['账户账号＿自己', '机构＿交易平台', 'other', '日期＿交易时间']
# ------------------------------------------------------
# icicib.pkl
# icicib
# [None, None, None, None]
# ------------------------------------------------------
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', None]
# ------------------------------------------------------
# 11107 ^Dear Customer\, acct .* has been debited for .* on .* towards linked .* UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 11108 ^Dear Customer\, Your a\/c no\. .* is credited by .* on .* by a\/c linked to mobile .* \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# ['账户账号＿自己', '金额＿转出', None, None]
# ------------------------------------------------------
# 11110 ^Dear Customer\, your Account .* has been credited with INR .* on .* Info\: .* The Available Balance is INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# 11112 ^Dear Customer\, Your a\/c no\. .* is debited for .* on .* and a\/c .* credited \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 11113 ^Dear Customer\, txn of INR .* using Credit Card .* done at .* on .* Avbl Cr lmt\:INR .* For dispute\,call 04033667777\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '银行卡号＿自己', '机构＿交易平台', '日期＿交易时间', '金额＿信用额度']
# ------------------------------------------------------
# 11114 ^You have initiated a txn of INR .* at .* on ICICI Bank Card .* OTP is .* DONT SHARE WITH ANYONE\. BANK NEVER CALLS TO VERIFY OTP\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '机构＿交易平台', '银行卡号＿自己', 'other']
# ------------------------------------------------------
# 11115 ^You have initiated a txn of INR .* at .* on ICICI Bank Card .* OTP is .* DONT SHARE IT WITH ANYONE\. BANK NEVER CALLS TO VERIFY OTP\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '机构＿交易平台', '银行卡号＿自己', 'other']
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 11118 ^Dear Customer\, acct .* has been debited for .* on .* and Acct .* is credited\. UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 11119 ^Dear Customer\, Purchase of INR .* has been made on Debit Card linked to Acct .* on .* Info\: .* The Available Balance is INR .*$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '账户账号＿自己', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# ['金额＿转出', None, None]
# ------------------------------------------------------
# 11121 ^Dear Customer\, stmt for Credit Card .* has been sent to .* Total amt of Rs\. .* or Min\. amt of Rs\. .* is due by .*$
# 短信类型:  信用卡＿还款提醒
# ['银行卡号＿自己', 'other', '金额＿应还金额', '金额＿最小应还金额', '日期＿交易时间']
# ------------------------------------------------------
# 11123 ^Dear Customer\, the Available Balance for your ICICI Bank Account .* is INR .* as on .*$
# 短信类型:  交易流水＿余额
# ['账户账号＿自己', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 11124 ^Dear Customer\, cash deposit of Rs\. .* to Account .* has been initiated through INSTA Banking\. Please quote Reference .* at the counter\. You will get another SMS confirming the completion of transaction\. Request for a hard copy receipt\, if you do not receive the confirmation SMS\.$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', 'other']
# ------------------------------------------------------
# 11125 ^Dear Customer\, Your a\/c no\. .* is credited by .* on .* by a\/c .* \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 11129 ^To make online payment of Rs\. .* you will need a One Time Password\(OTP\)\. NEVER SHARE THE OTP WITH ANYONE\. BANK NEVER CALLS TO VERIFY IT\. The OTP is .*$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other']
# ------------------------------------------------------
# 11130 ^Dear Customer\, Total Amount of INR .* and Minimum Amount of INR .* is due by .* on your Credit Card .* Please ignore if already paid\.$
# 短信类型:  信用卡＿还款提醒
# ['金额＿应还金额', '金额＿最小应还金额', '日期＿还款日期', '银行卡号＿自己']
# ------------------------------------------------------
# 11133 ^Dear Customer\, you have a collect request for .* from vpa .* Login to your mobile application to authorise the transaction\.$
# 短信类型:  交易流水＿转账
# ['金额＿应还金额', 'other']
# ------------------------------------------------------
# 11135 ^Dear Customer\, your Account .* has been credited with salary of INR .* on .* Info\: .* The Available Balance is INR .*$
# 短信类型:  交易流水＿余额
# ['账户账号＿自己', '金额＿薪资', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# 11138 ^Dear Customer\, Your fund transfer request for .* on .* could not be processed\. Please try later\. \(IMPS Ref no\. .*$
# 短信类型:  账号异常＿扣款失败
# ['金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11141 ^Dear Customer\, Refund of INR .* from .* has been credited to your Credit Card .* on .* For details\, please call our Customer Care\.$
# 短信类型:  交易流水＿转账
# ['金额＿转入', 'other', '银行卡号＿自己', '日期＿交易时间']
# ------------------------------------------------------
# 11144 ^Dear Customer\,ECS transaction of Rs\. .* towards .* from Account .* has been returned due to reason \- INSUFFICIENT .* on .*$
# 短信类型:  账号异常＿余额不足
# ['金额＿转出', '机构＿交易平台', '账户账号＿自己', 'other', '日期＿交易时间']
# ------------------------------------------------------
# 11145 ^Cash deposit transaction of Rs\. .* for Account .* has been completed on .* vide transaction reference .*$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11156 ^Dear Customer\, Your fund transfer request for .* on .* is declined as beneficiary account no\. or IFSC code is invalid \(IMPS Ref no\. .*$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 11160 ^Dear Customer\, you have made a payment of Rs\. .* to ARTHASHASTRA FINTECH PRIVATE LIMITED vide eazypay reference ID .*$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 11163 ^Dear Customer\, Total Amount Due on Credit Card .* is INR .* Amt will be debited from your bank account on or before .* Pls ignore if paid\.$
# 短信类型:  信用卡＿还款提醒
# ['银行卡号＿自己', '金额＿应还金额', '日期＿还款日期']
# ------------------------------------------------------
# 11166 ^Payment overdue on your Credit Card .* is affecting your credit history with CIBIL\. This may prevent you from getting a loan or a credit card from any bank in future\. To avoid further damage to your credit .* pay the total amt due .* or the min amt .* imm\.Pl ignore if .*$
# 短信类型:  信用卡＿逾期警告
# ['银行卡号＿自己', 'other', '金额＿应还金额', '金额＿最小应还金额', 'other']
# ------------------------------------------------------
# ['账户账号＿自己', None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 11172 ^NEFT Transaction with reference number .* for .* has been credited to the beneficiary account on .* at .*$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11176 ^Dear Customer\, Cheque .* for INR .* issued from your Account .* has returned on .* due to reason \- .*$
# 短信类型:  账号异常＿扣款失败
# ['other', '金额＿转出', '账户账号＿自己', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11177 ^Dear Customer\,transaction of INR .* on Credit Card .* has declined due to incorrect CVV or expiry date of the card\. Pls retry with correct details\.$
# 短信类型:  账号异常＿扣款失败
# ['金额＿转出', '银行卡号＿自己']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 11181 ^You have initiated a txn of USD .* at .* on ICICI Bank Card .* OTP is .* DONT SHARE WITH ANYONE\. BANK NEVER CALLS TO VERIFY OTP\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other', '银行卡号＿自己', 'other']
# ------------------------------------------------------
# [None]
# ------------------------------------------------------
# 11187 ^Dear Customer\, Total Amount Due of Rs\. .* on Credit Card .* was due on .* Please pay the Minimum Amount Due of Rs\. .* immediately for uninterrupted usage of the card\. For payment options\, visit www\.icicibank\.com\/pay \. Please ignore if already paid\.$
# 短信类型:  信用卡＿逾期警告
# ['金额＿应还金额', '银行卡号＿自己', '日期＿还款日期', '金额＿最小应还金额']
# ------------------------------------------------------
# 11188 ^Dear Customer\, Payment of your ICICI Bank Credit card .* is still pending\. We send this message\, as we are not able to reach you\. Pls pay the total overdue of .* imm\, and avoid adverse impact on your track record with credit bureaus\. For payment pickup pl call us at .* Ignore if already paid\.$
# 短信类型:  信用卡＿逾期警告
# ['银行卡号＿自己', '金额＿应还金额', 'other']
# ------------------------------------------------------
# 11191 ^Reference .* for Cash withdrawal of Rs\. .* from Acct .* has been initiated through INSTA Banking\. Pls quote this ref no\. to the Cash Teller\.$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', '账户账号＿自己']
# ------------------------------------------------------
# 11193 ^Dear Customer\, Payment of INR .* has been received towards your ICICI Bank Credit Card .* on .* through NEFT\. Thank you\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '银行卡号＿自己', '日期＿交易时间']
# ------------------------------------------------------
# 11194 ^.* Dear Customer\,As requested by you\,your transaction of INR .* on ICICI Bank Credit Card .* has been converted into .* EMIs on .*$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', '银行卡号＿自己', 'other', '日期＿交易时间']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 11216 ^You have initiated a txn of .* at Skrill .* on ICICI Bank Card .* OTP is .* DONT SHARE WITH ANYONE\. BANK NEVER CALLS TO VERIFY OTP\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other', '银行卡号＿自己', 'other']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 11221 ^Dear Customer\, The credit limit for your ICICI Bank Credit Card .* has been changed from INR .* to INR .* on .*$
# 短信类型:  交易流水＿余额
# ['银行卡号＿自己', 'other', '金额＿信用额度', '日期＿交易时间']
# ------------------------------------------------------
# 11228 ^Dear Customer\,your Account .* has been credited with INR .* on .* Info\. Aadhaar Payment Bridge System APBS\/IOC Ref .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11234 ^\(1\/2\) Dear Customer\, your Account .* has been credited with INR .* on .* Info\: .* The Available Balance is INR$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11240 ^To recharge your .* for Rs\. .* you will need an OTP\. NEVER SHARE .* WITH ANYONE\. BANK NEVER CALLS TO VERIFY IT\. The OTP is .*$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', 'other', 'other']
# ------------------------------------------------------
# ['other', 'other']
# ------------------------------------------------------
# ['other', 'other', 'other']
# ------------------------------------------------------
# ['other', 'other', 'other', 'other']
# ------------------------------------------------------
# ['other', 'other', 'other', None]
# ------------------------------------------------------
# [None, None, None, None, None, None]
# ------------------------------------------------------
# 11258 ^Dear Customer\, Overdraft .* for .* against Deposit\(s\) with ICICI Bank has been .* on .* For dtls\, pls call our .*$
# 短信类型:  账号异常＿扣款失败
# ['交易流水＿转账', '金额＿转出', 'other', '日期＿交易时间', 'other']
# ------------------------------------------------------
# unionb.pkl
# unionb
# ['账户账号＿自己', None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 5108 ^Your a\/c no\. .* is credited for .* on .* by a\/c linked to mobile .* \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# [None, None, None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 5112 ^Avl Bal in Your A\/c .* is INR Cr .* as on .* IST \.$
# 短信类型:  交易流水＿余额
# ['账户账号＿自己', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# [None, None, None, None, None, None]
# ------------------------------------------------------
# 5123 ^Your .* A\/c .* is debited .* Rs\. .* on .* for .* a\/c credited vide UTR no\. .*$
# 短信类型:  交易流水＿转账
# ['other', '账户账号＿自己', 'other', '金额＿转出', '日期＿交易时间', '机构＿交易平台', 'other']
# ------------------------------------------------------
# 5128 ^Transaction for .* to .* has been completed successfully with reference id .*$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other', 'other']
# ------------------------------------------------------
# 5133 ^Cheque .* is Lodged through clearing in your .* A\/c .* to credit Rs\. .* on .*$
# 短信类型:  信用卡＿还款提醒
# ['other', 'other', '账户账号＿自己', '金额＿应还金额', '日期＿还款日期']
# ------------------------------------------------------
# 5134 ^Avl Bal in Your A\/c .* is INR Dr .* as on .* IST \.$
# 短信类型:  交易流水＿余额
# ['账户账号＿自己', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 5138 ^OTP for your txn for Rs .* towards PMT is .* Cross check OTP Ref Id .* on screen\. Do not share OTP with anyone\. Union Bank\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other', 'other']
# ------------------------------------------------------
# 5140 ^Dear Customer\,Your SB Account No .* is credited by LPG subsidy Rs .* on .* Avbl Bal .* APPLY DEBITCARD ONLINE .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '金额＿余额', 'other']
# ------------------------------------------------------
# ['账户账号＿自己', None, None, None]
# ------------------------------------------------------
# 5147 ^Dear Customer\,Your SB Account No .* is credited by LPG subsidy Rs .* on .* Avbl Bal .* DISCOUNT CODE FNP15UBI FOR FERNSNPETALS$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# [None, None, None, None, None, None, None, None]
# ------------------------------------------------------
# 5150 ^Dear customer\,perhaps you have missed payment of your installment of .* in your A\/c .* with Union Bank\.Kindly ignore if already paid$
# 短信类型:  sms_other
# ['other', 'other']
# ------------------------------------------------------
# 5151 ^Dear Customer\,Please make Payment of Rs\. .* due in your A\/c .* with Union Bank at Branch .* immediately\.Kindly Ignore .*$
# 短信类型:  信用卡＿逾期警告
# ['金额＿应还金额', '账户账号＿自己', 'other', 'other']
# ------------------------------------------------------
# 5153 ^Bank is replacing your existing magstripe debit card with EMV card\. Please collect your new debit card from the branch .* as old card will be blocked on .*$
# 短信类型:  账号异常＿卡号冻结
# ['other', '日期＿交易时间']
# ------------------------------------------------------
# 5154 ^Your a\/c no\. .* is debited for .* on .* and a\/c .* credited \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 5156 ^Your .* A\/c .* in .* Clg\. Credited Rs\. .* on .* by Clearing\. Bal is Rs\. .* Subject To Chq .* CODE FNP15UBI FOR FERNSNPETALS$
# 短信类型:  交易流水＿转账
# ['other', '账户账号＿自己', '机构＿交易平台', '金额＿转入', '日期＿交易时间', '金额＿余额', 'other']
# ------------------------------------------------------
# 5157 ^Your .* claim for .* \/\- dated .* lodged successfully\. Reference no\. .*$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# ['other', 'other', 'other', 'other']
# ------------------------------------------------------
# ['other', 'other']
# ------------------------------------------------------
# scisms.pkl
# scisms
# 11664 ^Dear SBI UPI User\, your account is debited INR .* on Date .* by UPI Ref No .* YONO \@ www\.yonosbi\.com$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 11666 ^Your a\/c no\. .* is credited by .* on .* by a\/c linked to mobile .* \(IMPS Ref no .* Download YONO \@ www\.yonosbi\.com\.$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None]
# ------------------------------------------------------
# 11669 ^Your A\/C .* Credited INR .* on .* \-Deposit of Cash at .* ATM\. A\/c Balance INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# 11670 ^Your A\/C .* has a credit by Transfer of Rs .* on .* Avl Bal Rs .* Download YONO \@ www\.yonosbi\.com$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# 11671 ^Your A\/C .* Credited INR .* on .* \-Deposit by transfer from .* A\/C Bal INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '机构＿交易平台', '金额＿余额']
# ------------------------------------------------------
# 11672 ^Dear customer\,your transaction at .* has been declined due to insufficient fund in your account\.$
# 短信类型:  账号异常＿余额不足
# ['other']
# ------------------------------------------------------
# 11673 ^Your a\/c no\. .* is debited for .* on .* and a\/c .* credited \(IMPS Ref no .* Download YONO \@ www\.yonosbi\.com\.$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 11674 ^INR .* credited to your A\/c No .* on .* through NEFT with UTR .* by .*$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 11675 ^Your A\/C .* Debited INR .* on .* \-Transferred to INVESTMENT INTERMEDI\. A\/C Balance INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# 11676 ^Your A\/C .* Credited INR .* on .* \-Deposited by Cash by .* \. A\/C Bal INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# 11677 ^Your A\/C .* has a debit by transfer of Rs .* on .* Avl Bal Rs .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 11679 ^Thank you for using State Bank Internet Banking\. Reference No\. for transaction of Rs\. .* from A\/c ending .* on .* at .* is .* Download YONO \@ www\.yonosbi\.com$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '账户账号＿自己', '日期＿还款日期', 'other', 'other']
# ------------------------------------------------------
# 11680 ^Dear SBI UPI User\, you have received .* of INR .* from .* on Date .* \(Ref No .*$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转入', 'other', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11681 ^Dear SBI UPI User\, Your a\/c no\. .* is credited with INR .* on .* for reversal of transaction \(UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11682 ^Your A\/C .* Debited INR .* on .* \-Transferred to .* A\/C Balance INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# ['金额＿转入', '账户账号＿自己', None]
# ------------------------------------------------------
# 11684 ^Hold for INR .* created in your AC .* on .* Download YONO \@ www\.yonosbi\.com$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间']
# ------------------------------------------------------
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', None]
# ------------------------------------------------------
# 11689 ^Mandate Registration\- UMRN .* for Rs .* issued to .* received today\.In case of any issues pls contact branch$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', 'other']
# ------------------------------------------------------
# 11690 ^INR .* credited to your A\/c No .* on .* through NEFT with UTR .* by .* PVT LTD$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 11691 ^Your NEFT of Rs .* with UTR .* DTD .* credited to Beneficiary AC NO\. .* at .* on .* at .*$
# 短信类型:  交易流水＿转账
# ['金额＿转入', 'other', '日期＿交易时间', '账户账号＿他人', 'other', 'other', 'other']
# ------------------------------------------------------
# ['账户账号＿自己', '金额＿转出', None, None]
# ------------------------------------------------------
# 11693 ^INR .* credited to your A\/c No .* on .* through NEFT with UTR .* by SMARTCOIN FINANCIALS$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11694 ^Dear customer\,your txn at .* declined due to incorrect PIN\.Please enter .* correct PIN\.$
# 短信类型:  账号异常＿扣款失败
# ['other', 'other']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 11699 ^Your A\/C .* has a credit by Cheque of Rs .* on .* Avl Bal Rs .* Download YONO \@ www\.yonosbi\.com$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# 11700 ^Dear customer\,your txn at ATM .* declined as your daily withdrawal limit will exceed with the requested amount\.$
# 短信类型:  账号异常＿扣款失败
# ['other']
# ------------------------------------------------------
# 11702 ^Your A\/C .* has a Cash withdrawal of Rs .* on .* \. Avl Bal Rs .* Download YONO \@ www\.yonosbi\.com$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# 11705 ^Your AC .* Debited INR .* on .* \-Towards cash payment by Cheque .* Avl Bal INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# 11708 ^PFMS generated payment\/DBT of Rs\. .* credited to your .* on .*$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 11710 ^Chq No .* for INR .* issued frm AC .* dishonoured\.Chrg INR .* deducted\.$
# 短信类型:  sms_other
# ['other', 'other', 'other', 'other']
# ------------------------------------------------------
# ...
# ------------------------------------------------------
# 2912 ^Dear Customer cash withdrawal limit on your Credit Card ending .* has been disabled as per internal guidelines \-T\&C apply$
# 短信类型:  账号异常＿卡号冻结
# ['银行卡号＿自己']
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 2920 ^Dear Customer\, We acknowledge receipt of Payment by Cash via Receipt No\. .* for Rs\. .* \/\- towards Loan A\/c No\. .* \.$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', 'other']
# ------------------------------------------------------
# [None, None]
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 2935 ^Dear Customer\,Payments on your HDFC Bank \-Consumer Durable Life Style .* are overdue\.Please pay .* towards pending EMI\.Timely payments will help you avoid levy of fees and charges\.Check your score at https\:\/\/goo\.gl\/tM76D4\.Please ignore if you have already paid$
# 短信类型:  信用卡＿还款提醒
# ['other', '金额＿应还金额']
# ------------------------------------------------------
# 2939 ^Payment of .* on your HDFC Bank Card .* has been declined\. This type of transaction is not allowed as per regulatory guidelines\.$
# 短信类型:  账号异常＿扣款失败
# ['金额＿转出', '银行卡号＿自己']
# ------------------------------------------------------
# 2947 ^Copy of RC Book\, Invoice\, Ins Policy for vehicle loan .* with HDFC Bank has not been submitted yet\.Pls submit at the earliest at any Loan Service centre\.$
# 短信类型:  贷前申请＿申请交互
# ['账号＿借款编号']
# ------------------------------------------------------
# 2948 ^Dear HdfcBank Cardmember\, Lien Marked for .* on .* in acct ending .* due to autopay return for card .*$
# 短信类型:  信用卡＿还款提醒
# ['金额＿应还金额', '日期＿还款日期', '账户账号＿自己', '账户账号＿他人']
# ------------------------------------------------------
# 2949 ^Dear cardmember\, Total outstanding on ur HDFCBank card ending .* is .* Estmt alone is sent to ur Email ID for .* Pls refer the same for details$
# 短信类型:  信用卡＿还款提醒
# ['银行卡号＿自己', '金额＿余额', '日期＿还款日期']
# ------------------------------------------------------
# [None, None]
# ------------------------------------------------------
# 2953 ^Dear Customer\, Your ACH mandate form submitted towards repayment of your Loan No\. .* with HDFC Bank has been returned by .* BANK due to \" .* \" \.Request you to access the fresh ACH Mandate form from our website link http\:\/\/www\.hdfcbank\.com\/assets\/pdf\/ACH\-Mandate\-Format\.pdf and submit at our Retail Loan Service Centre http\:\/\/bit\.ly\/29z1UV4 at the earliest for seamless loan repayment\.$
# 短信类型:  贷前申请＿审核拒绝
# ['other', 'other', 'other']
# ------------------------------------------------------
# [None]
# ------------------------------------------------------
# 2957 ^Dear Customer\, Your bank has returned the .* EMI of .* thru ECS Debit for Loan No .* reason ECS MANDATE NOT .* Please visit your Bank Branch urgently for registering the ECS Mandate\.$
# 短信类型:  贷前申请＿审核拒绝
# ['日期＿交易时间', '金额＿放款金额', '账号＿借款编号', 'other']
# ------------------------------------------------------
# 2958 ^Your current payment record is\: May OK Jun OK Jul OK Aug .* XX \.You have missed a payment for your HDFCBank CreditCard ending in .* Revert to your non\-defaulting status by clicking https\:\/\/goo\.gl\/pE0b71 if you are a HDFC customer or https\:\/\/goo\.gl\/yvUayf for other banks and making a payment of Rs\. .*$
# 短信类型:  信用卡＿还款提醒
# [None, '银行卡号＿自己', '金额＿应还金额']
# ------------------------------------------------------
# 2959 ^Your current payment record is\: Jun OK Jul OK Aug .* XX \.You have missed a payment for your HDFCBank CreditCard ending in .* Revert to your non\-defaulting status by clicking https\:\/\/goo\.gl\/pE0b71 if you are a HDFC customer or https\:\/\/goo\.gl\/yvUayf for other banks and making a payment of Rs\. .*$
# 短信类型:  信用卡＿还款提醒
# ['other', '银行卡号＿自己', '金额＿应还金额']
# ------------------------------------------------------
# albank.pkl
# albank
# 2270 ^Your a\/c no\. .* is debited by .* on .* and credited to .* Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 2271 ^Your A\/c .* is debited through ATM Card by Rs\. .* Total Bal \: Rs\. .* CR Clr Bal \: Rs\. .* CR .* \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '金额＿余额', '金额＿余额', '日期＿交易时间', '日期＿交易时间']
# ------------------------------------------------------
# 2273 ^Your a\/c no\. .* is credited by .* on .* sent by .* Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# [None, None, None, None, None, None, None]
# ------------------------------------------------------
# 2275 ^Your A\/c .* is debited through ATM by Rs\. .* Total Bal \: Rs\. .* CR Clr Bal \: Rs\. .* CR .* \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '金额＿余额', '金额＿余额', '日期＿交易时间', '日期＿交易时间']
# ------------------------------------------------------
# 2276 ^Your A\/c .* is debited by Rs\. .* Bal after Debit is Rs\. .* CR .* MINIMUM BAL NOT MAINTAINED\.PL FUND YOUR A\/C\. \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '金额＿余额', '日期＿交易时间', '日期＿交易时间']
# ------------------------------------------------------
# [None, None]
# ------------------------------------------------------
# 2282 ^Your a\/c no\. .* is credited by .* on .* sent by goog\-payment\@okaxis\-GOOGLEPAY\(UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# [None, None, None, None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None, None, None]
# ------------------------------------------------------
# 2289 ^Your Account .* has been debited with Rs\. .* for Online E\-Payment through Internet Banking\. \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间']
# ------------------------------------------------------
# 2292 ^Your a\/c no\. .* is credited for .* on .* for reversal of unsuccessful transaction \(UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 2293 ^Your A\/c .* is debited by Rs\. .* through .* txn using Aadhaar No\. .* on .* \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '机构＿交易平台', 'other', '日期＿交易时间', '日期＿交易时间']
# ------------------------------------------------------
# 2294 ^Rs\. .* deducted as penal charges for fall in minimum balance of previous quarter \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '日期＿交易时间']
# ------------------------------------------------------
# 2298 ^Your a\/c no\. .* is credited by .* on .* sent by .* Ref no .* Fight Against Corruption\. Take e\-pledge on www\.pledge\.cvc\.nic\.in$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 2300 ^LPG Subsidy of Rs\. .* has been credited in your Account No\. .* \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间']
# ------------------------------------------------------
# [None, None, None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 2304 ^Your A\/c .* is debited by Rs\. .* Bal after Debit is Rs\. .* CR .* MINIMUM BAL NOT MAINTAINED\.PL FUND YOUR .* \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '金额＿余额', '日期＿交易时间', 'other', '日期＿还款日期']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 2308 ^NEFT transfer of Rs\. .* to .* BANK will be effected subject to realisation\. Ref No \: .* \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '机构＿交易平台', 'other', '日期＿交易时间']
# ------------------------------------------------------
# corpbk.pkl
# corpbk
# [None, None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None, None, None, None]
# ------------------------------------------------------
# 5801 ^Your a\/c no .* is debited for .* on .* and a\/c .* of .* is credited \(IMPS Ref no .* \)\.$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other', 'other']
# ------------------------------------------------------
# 5803 ^Dear Customer\, Your request for IMPS payment of Rs\. .* for the beneficiary IFSC .* a\/c .* has been .* From CorpBank$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other', '账户账号＿自己', 'other']
# ------------------------------------------------------
# 5805 ^Your A\/c .* in .* credited INR .* on .* by CASH\. Avl Bal is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '机构＿交易平台', '金额＿转入', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 5814 ^Your A\/c .* in .* debited INR .* on .* by CASH\. Avl Bal is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '机构＿交易平台', '金额＿转出', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# 5816 ^An amount of Rs\. .* has been debited from your A\/C .* for an online transaction done at .* using CorpNet banking\, Ref No\: .* From CorpBank$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '账户账号＿自己', 'other', 'other']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 5821 ^Your A\/c .* debited .* on .* by NEFT with UTR No \: .* \. Avl bal is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 5826 ^Returned\, .* for .* fvg .* rcvd for Db in ur A\/c .* in Clg\. Contact Branch\.$
# 短信类型:  sms_other
# ['other', 'other', 'other', 'other']
# ------------------------------------------------------
# ['other', 'other', 'other', 'other']
# ------------------------------------------------------
# ['other', 'other', 'other', 'other', 'other']
# ------------------------------------------------------
# 5833 ^INR .* debited to a\/c .* from ATM On .* \.Avl Bal .* \.Reversal in 2days for tech failure\.Call 18004252407 for help$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '账户账号＿自己', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# ['账户账号＿自己', None, None, None, None, None]
# ------------------------------------------------------
# 5835 ^Your a\/c no\. .* is credited for .* on .* for reversal of transaction \(UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 5838 ^Your a\/c no\. .* is credited for .* on .* for reversal of transaction \(IMPS Ref no .* \)\.$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# [None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 5845 ^Inward Clg Cheque\: .* for .* fvg .* presented in A\/c\: .* Contact your Branch if there is any discrepancy\.$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', 'other', '账户账号＿自己']
# ------------------------------------------------------
# 5846 ^Your request for the payment Rs\. .* has been executed successfully\. Ref No\: .* From CorpBank$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other']
# ------------------------------------------------------
# 5847 ^Dear Customer\, your account .* has been credited INR .* through NPCI Clearing on .* \. Avl Balance is INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# 5849 ^Due\, .* towards your loan A\/c .* inclusive of instalment\, payable on .* Contact branch for any clarification\. Pls ignore if paid$
# 短信类型:  贷后提醒＿到期提醒
# ['金额＿应还金额', '账号＿借款编号', '日期＿交易时间']
# ------------------------------------------------------
# 5853 ^Your A\/c .* in credited INR .* on .* by \. Avl Bal is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# iobchn.pkl
# iobchn
# [None, None, None, None, False]
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 4531 ^Your a\/c no\. .* is credited by .* on .* by a\/c linked to mobile .* Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 4532 ^Your a\/c no\. .* is debited for Rs\. .* on .* and a\/c .* credited \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 4534 ^You have done a Transaction .* IOB internet banking on .* for .* from A\/c no .*$
# 短信类型:  交易流水＿转账
# ['other', '日期＿交易时间', '金额＿转出', '账户账号＿自己']
# ------------------------------------------------------
# 4535 ^Your Avl Balance Acct \: .* is Rs .*$
# 短信类型:  交易流水＿余额
# ['账户账号＿自己', '金额＿余额']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 4539 ^You have done a Tax\/Bill payment through IOB internet banking on .* for .* from A\/c no .*$
# 短信类型:  交易流水＿转账
# ['日期＿交易时间', '金额＿转出', '账户账号＿自己']
# ------------------------------------------------------
# 4540 ^Your IOB Cheque No\. .* for Rs\. .* is presented today for clearing in your A\/C .* \.\.\.\.\.$
# 短信类型:  信用卡＿还款提醒
# ['other', '金额＿转出', '账户账号＿自己']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 4546 ^Dear Customer\,Your Loan A\/c .* with IOB is Overdue for .* days by .* as on .* \[SMA\-2\]\.Regularize to avoid punitive action\.$
# 短信类型:  贷后提醒＿逾期催收
# ['账号＿借款编号', '天数＿逾期天数', '金额＿应还金额', '日期＿还款日期']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 4553 ^Mandate\(Ref No\: .* issued to .* for Rs .* and frequency .* is received for processing\. In case of any issue please contact your branch$
# 短信类型:  账号异常＿扣款失败
# ['other', 'other', '金额＿转出', 'other']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 4560 ^Mandate\(Ref No\: .* issued to .* for Rs .* and frequency Monthly is accepted\. Applicable charges will be collected$
# 短信类型:  sms_other
# ['other', 'other', 'other']
# ------------------------------------------------------
# 4564 ^You have done a Transaction through IOB internet banking to Other Bank Account on .* for .* from A\/c no .*$
# 短信类型:  交易流水＿转账
# ['日期＿交易时间', '金额＿转出', '账户账号＿自己']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# axismr.pkl
# axismr
# 3400 ^Dear Customer\,in order to serve you better\, Axis Bank offers you an enhanced limit of .* on your Credit Card\.To avail SMS CLE .* to 5676782 by .*$
# 短信类型:  交易流水＿余额
# ['金额＿信用额度', 'other', 'other']
# ------------------------------------------------------
# 3404 ^Hi\, the .* in your current a\/c .* for the first 20 days of this month is .* Please fund your A\/c to avoid charges on MAB shortfall\. T\&C apply$
# 短信类型:  sms_other
# [None, None, None]
# ------------------------------------------------------

# %%
DF = pd.DataFrame()
for tt in ALL:
    DF_tmp = pd.DataFrame()
    length = len(tt[0].split(' '))
    DF_tmp['token'] = tt[0].split(' ')
    DF_tmp['lable'] = DF_tmp.token.apply(lambda x: tt[3][x] if x in tt[3] else np.nan)
    DF_tmp['sent_id'] = [tt[0].split(' ')[i] if i==0 else np.nan for i in range(len(DF_tmp))]
    DF_tmp['cls'] = [tt[4]]*length
    DF_tmp.sent_id=DF_tmp.sent_id.fillna(method='ffill')
    DF = DF.append(DF_tmp)
    DF = DF[~DF.cls.isnull()]
DF = DF.fillna(value='other')

DF['sent_id'] = ['sent_' if i == 0 else np.nan for i in DF.index]
DF['idx_num'] = range(DF.shape[0])
DF['sent_id'] = DF.apply(lambda x: str(x.sent_id) + str(x.idx_num), axis=1)
DF['sent_id'] = DF.sent_id.apply(lambda x: x if x.startswith('sent') else np.nan)
DF.sent_id = DF.sent_id.fillna(method='ffill')
DF = DF.drop(['idx_num'], axis=1)
DF = DF[DF.cls != False]
DF.shape
# Out:
# (29300, 4)

# %% [raw]
# DF.to_csv('gsm_ALL.csv', header=False)

# %% [markdown]
# ### 唯一测试集；

# %%
Test_DF = pd.read_csv('gsmTst100.csv', header=None).iloc[:,1:]
Test_DF.columns = ['token', 'lable', 'sent_id', 'cls']

sms_te = Test_DF.groupby('sent_id').apply(lambda x: ' '.join(x.token.tolist()).lower())
cls_te = Test_DF.groupby('sent_id').apply(lambda x: x.cls.tolist()[0])
df3_te = pd.DataFrame(columns=['sms', 'cls'])
df3_te.sms = sms_te
df3_te.cls = cls_te

df3_te.shape
# Out:
# (100, 2)

# %%
DF = DF[~DF.sent_id.isin(Test_DF.sent_id)]
DF.shape
# Out:
# (26883, 4)

# %%
## 造假n倍
dupli = 10
DF = DF[DF.cls != False]
df = create_fake_label(DF, dupli)
df2 = fake2real_v2(df, dupli)

# %%
# 过采样欠采样；2bDone

# %%
def get_cos_similarity(sms, templates):
    '''计算一条新sms 与 每个 template 相似度;'''
    def cos_sim(a, b):
        return dot(a, b) / (norm(a) * norm(b))
    return [cos_sim(i, sms) for i in templates]


def tfIdfVector(corpus):
    '''
    corpus is a list of sentences:
    ['This is an example', 'hello world', ...]
    '''
    vectorizer = CountVectorizer()
    transformer = TfidfTransformer()
    x = vectorizer.fit_transform(corpus)
    tfidf = transformer.fit_transform(x)
    return tfidf.toarray()

# def newAndTemplate(template_df, new_sms, thresh=None):
#     '''
#     new_sms: test samples
#     '''
#     corpus, labels = template_df.sms.tolist(), template_df.label.tolist()
#     num_sms = len(new_sms)
#     for single in new_sms:
#         corpus.append(single.lower())
#     all_tfidf = tfIdfVector(corpus)
#     template_tfidf = all_tfidf[:-num_sms]
#     instances_tfidf = all_tfidf[-num_sms:]
#     adj_mat = cosine_similarity(all_tfidf)
#     print('adj mat shape:{}'.format(adj_mat.shape))
#     if thresh:
#         print('thresh:{}'.format(thresh))
#         adj_mat-=np.identity(len(adj_mat))
#         G2 = nx.from_numpy_matrix((adj_mat > thresh)*1)
#     else:
#         G2 = nx.from_numpy_matrix(adj_mat)
#     print(G2.number_of_edges())
#     for i in range(len(G2.nodes())):
#         G2.node[i]['vec'] =  all_tfidf[i]
#         G2.node[i]['text'] = corpus[i]
#         temp_label = labels[i] if i < len(labels) else 0
#         G2.node[i]['label'] = temp_label
#     return G2

def GraphBuild(template_df, new_sms, K=10, thresh=None):
    '''
    之前版本没考虑到采样需要全图遍历；故在入图过程就把K_nerghs当作点属性加进去；
    new_sms: test samples, df type;
    
    '''
    def findNeighsK(arr, K):
        K+=1 #入图时neighs 不包括自己，故这里先加一个保证去除自己之后仍然有K neighs;
        idx=np.argpartition(arr, -K)[-K:]
        return idx

    corpus, labels = template_df.sms.tolist(), template_df.cls.tolist()
    new_labels = new_sms.cls.tolist()
    new_sms = new_sms.sms.tolist()
    num_sms = len(new_sms)
    for single in new_sms:
        corpus.append(single.lower())
    for single in new_labels:
        labels.append(single)
    all_tfidf = tfIdfVector(corpus)
    adj_mat = cosine_similarity(all_tfidf)
    print('adj mat shape:{}'.format(adj_mat.shape))
    G = nx.Graph()
    G.add_nodes_from(range(len(adj_mat)))
    for i in range(len(G.nodes())):
        G.node[i]['vec'] =  all_tfidf[i]
        G.node[i]['text'] = corpus[i]
        G.node[i]['label'] = labels[i]
        G.node[i]['neighs_k'] = set(findNeighsK(adj_mat[i], K)) - set([i])
    return G

# %% [raw]
# # graphsage 怎么设计盲测？
# 首先必须要有相似度关联；
# 故，盲测集必须入图；
# 只要保证盲测集不参与训练即可，无需mask
# 什么时候需要mask? 当你要半监督的时候，只有node & path
# 没label,通过mask不参与反向传播；
# 既然如此，我何必需要这些 ‘无label node’ 入图呢？
# 首先，这些node 提供了边点信息，为有label node 的 agg&enc；
# 所以虽然这些点不作为target参与BP,
# 但是作为target的邻居，参与了BP;
# 盲测集入图，半监督设置，盲测点不提供label;

# %%
# df2 = DF

# %%
sms = df2.groupby('sent_id').apply(lambda x: ' '.join(x.token.tolist()).lower())
cls = df2.groupby('sent_id').apply(lambda x: x.cls[0])
df3 = pd.DataFrame(columns=['sms', 'cls'])
df3.sms = sms
df3.cls = cls

# %%
g4 = GraphBuild(df3, df3_te)
# Out:
# adj mat shape:(1195, 1195)

# %%
"""
Set of modules for aggregating embeddings of neighbors.
"""
class MeanAggregator_QBv2(nn.Module):
    """
    adjMat@embMat: [bs, uniqueNode]@[uniqueNode, F]=[bs, F]
    
    要改，之前没注意每次采样全图遍历；
    如无必要，不要让一个实例挂一个毒瘤: G (20G内存)
    """
    def __init__(self, features, cuda=False, gcn=False): 
        """
        Initializes the aggregator for a specific graph.
        features -- function mapping LongTensor of node ids to FloatTensor of feature values.
        cuda -- whether to use GPU;
        gcn --- whether to perform concatenation GraphSAGE-style, or add self-loops GCN-style
        """
        super(MeanAggregator_QBv2, self).__init__()
        self.features = features
        self.cuda = cuda
        self.gcn = gcn
        
    def forward(self, nodes, to_neighs, num_sample=10):
        """
        nodes --- list of nodes in a batch, [bs]
        to_neighs --- list of sets, 
                      each set is the set of neighbors for node in batch
        num_sample --- number of neighbors to sample. 
        """
        _set = set
        if not num_sample is None:
            _sample = random.sample
            samp_neighs = [_set(_sample(to_neigh, num_sample))
                           if len(to_neigh) >= num_sample else to_neigh 
                           for to_neigh in to_neighs]
        else:
            samp_neighs = to_neighs
    
        # 纳入target idx;
        if self.gcn:
            samp_neighs = [set.union(samp_neigh, set([nodes[i]])) for i, samp_neigh in enumerate(samp_neighs)]
        unique_nodes_list = list(set.union(*samp_neighs))
        unique_nodes = {n:i for i,n in enumerate(unique_nodes_list)}
        mask = Variable(torch.zeros(len(samp_neighs), len(unique_nodes)))
        column_indices = [unique_nodes[n] for samp_neigh in samp_neighs for n in samp_neigh]   
        row_indices = [i for i in range(len(samp_neighs)) for j in range(len(samp_neighs[i]))]
        mask[row_indices, column_indices] = 1
        if self.cuda:
            mask = mask.cuda()
        num_neigh = mask.sum(1, keepdim=True)
        mask = mask.div(num_neigh)
        if self.cuda:
            embed_matrix = self.features(torch.LongTensor(unique_nodes_list).cuda())
        else:
            embed_matrix = self.features(torch.LongTensor(unique_nodes_list))
        to_feats = mask.mm(embed_matrix)
        return to_feats

    
class Encoder_QBv2(nn.Module):
    """
    ([cls, 2f]@[2f, bs]).T = [bs, cls] 
    Encodes a node's using 'convolutional' GraphSage approach
    """
    def __init__(self, features, feature_dim, 
            embed_dim, adj_lists, aggregator,
            num_sample=10,
            base_model=None, gcn=False, cuda=False, 
            feature_transform=False): 
        super(Encoder_QBv2, self).__init__()

        self.features = features
        self.feat_dim = feature_dim
        self.adj_lists = adj_lists
        self.aggregator = aggregator
        self.num_sample = num_sample
        if base_model != None:
            self.base_model = base_model

        self.gcn = gcn
        self.embed_dim = embed_dim
        self.cuda = cuda
        self.aggregator.cuda = cuda
        self.weight = nn.Parameter(
                torch.FloatTensor(embed_dim, self.feat_dim if self.gcn else 2 * self.feat_dim))
        init.xavier_uniform(self.weight)


    def forward(self, nodes):
        """
        Generates embeddings for a batch of nodes.
        nodes     -- list of nodes; [bs]
        operations: 已知self_feat: [bs, F]
                    再agg_feat: [bs, F]
                    然后concat([agg_feat, self_feat]): [bs, 2F]
                    然后W:[F2, 2F] 
                    relu(W @[bs,2F].T) : [F2, bs] 
        """
        neigh_feats = self.aggregator.forward(nodes, [self.adj_lists[int(node)] for node in nodes], 
                self.num_sample)
        if not self.gcn:
            if self.cuda:
                self_feats = self.features(torch.LongTensor(nodes).cuda())
            else:
                self_feats = self.features(torch.LongTensor(nodes))
            combined = torch.cat([self_feats, neigh_feats], dim=1)
        else:
            combined = neigh_feats
        combined = F.relu(self.weight.mm(combined.t()))
        return combined



class SupervisedGraphSage_QB(nn.Module):
    def __init__(self, num_classes, enc):
        super(SupervisedGraphSage_QB, self).__init__()
        self.enc = enc
        self.weight = nn.Parameter(torch.FloatTensor(num_classes, enc.embed_dim))
        init.xavier_uniform(self.weight)
        self.loss = nn.NLLLoss(reduce=False)
        self.logsoftmax = nn.LogSoftmax(dim=-1)
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, nodes, softmax=False):
        embeds = self.enc(nodes)
        scores = self.weight.mm(embeds)
        if softmax:
            return self.softmax(scores.t())
        return scores.t()

    def loss_softmax_mask(self, nodes, labels, mask=None):
        '''
        nodes shape: [N];
        labels shape: [N];
        mask shape: [N];
        '''
        if mask is None:
            mask = torch.ones(len(labels))
        logits = self.forward(nodes)
        A_soft = self.logsoftmax(logits)
        output = self.loss(A_soft, labels.squeeze())
        loss = output*mask.type(torch.float)
        loss = sum(loss)/sum(mask)
        return loss
    
    
def result(G, output, label_idx, idx2label):
    score, pred = output.max(dim=-1)
    sms = [G.node[i]['text'] for i in label_idx]
    df = pd.DataFrame()
    df['sms']= sms
    df['score']=score.data
    df['pred']=[idx2label[i] for i in pred.numpy()]
    df['label']=[g4.node[i]['label'] for i in label_idx]
    return df

# %%
def load_india_sms(G):
    feat_data = [G.node[i]['vec'] for i in G.nodes]
    labels = [G.node[i]['label'] for i in G.nodes]
    adj_lists = [G.node[i]['neighs_k'] for i in G.nodes]
    return feat_data, labels, adj_lists

# %%
np.random.seed(1)
random.seed(1)
feat_data, labels, adj_lists = load_india_sms(g4)
idx2label = {i:j for i, j in enumerate(np.unique(labels))}
label2idx = {j:i for i,j in idx2label.items()}
labels = np.array([label2idx[i] for i in labels])
num_cls = len(np.unique(labels))
features = nn.Embedding(len(feat_data), len(feat_data[0]))
features.weight = nn.Parameter(torch.FloatTensor(feat_data), requires_grad=False)
node_F = len(feat_data[0])
agg1 = MeanAggregator_QBv2(features, cuda=False, gcn=True)
enc1 = Encoder_QBv2(features, node_F, 128, adj_lists, agg1, num_sample=5, gcn=True, cuda=False)
agg2 = MeanAggregator_QBv2(lambda nodes : enc1(nodes).t(), cuda=False, gcn=True)
enc2 = Encoder_QBv2(lambda nodes : enc1(nodes).t(), 
               enc1.embed_dim, node_F, adj_lists, agg2, num_sample=5, gcn=True, cuda=False)

# %%
graphsage = SupervisedGraphSage_QB(num_cls, enc2)
#graphsage.cuda()
#rand_indices = np.random.permutation(len(node_list))
nodes = list(g4.nodes)
val = nodes[:50]
test_nodes = list(g4.nodes)[-df3_te.shape[0]:]
train = nodes[50:-len(test_nodes)]
optimizer = torch.optim.SGD(filter(lambda p : p.requires_grad, graphsage.parameters()), lr = 0.8)
times = []
Loss = []
print('GO')
for batch in range(5000):
    batch_nodes2 = train[:200]
    batch_idx = copy.copy(train[:200])
    random.shuffle(train)
    start_time = time.time()
    optimizer.zero_grad()
    loss = graphsage.loss_softmax_mask(batch_nodes2,
            Variable(torch.tensor(labels[np.array(batch_idx)])))
    loss.backward()
    optimizer.step()
    end_time = time.time()
    times.append(end_time - start_time)
#     print(graphsage.forward(val, True)[0].sum())
    if batch%100 == 0:
        train_loss = graphsage.loss_softmax_mask(train,
            Variable(torch.tensor(labels[np.array(train)])))
        val_loss = graphsage.loss_softmax_mask(val,
            Variable(torch.tensor(labels[np.array(val)])))
        print('batch:{}; train_loss:{}; val_loss:{}'.format(batch, train_loss.data, val_loss.data))
    Loss.append(loss.data)
# Out:
# GO
# batch:0; train_loss:2.832213878631592; val_loss:2.8324925899505615
# batch:100; train_loss:1.5947654247283936; val_loss:1.8075058460235596
# batch:200; train_loss:1.4725337028503418; val_loss:1.6563823223114014
# batch:300; train_loss:1.4057425260543823; val_loss:1.5822253227233887
# batch:400; train_loss:1.3588413000106812; val_loss:1.5120530128479004
# batch:500; train_loss:1.32341730594635; val_loss:1.4668365716934204
# batch:600; train_loss:1.2836371660232544; val_loss:1.4461112022399902
# batch:700; train_loss:1.2555619478225708; val_loss:1.345914602279663
# batch:800; train_loss:1.2260210514068604; val_loss:1.3115342855453491
# batch:900; train_loss:1.2036675214767456; val_loss:1.2710866928100586
# batch:1000; train_loss:1.1764490604400635; val_loss:1.2641510963439941
# batch:1100; train_loss:1.1402173042297363; val_loss:1.1702533960342407
# batch:1200; train_loss:1.1253052949905396; val_loss:1.1592535972595215
# batch:1300; train_loss:1.1036477088928223; val_loss:1.0744022130966187
# batch:1400; train_loss:1.0779008865356445; val_loss:1.1162515878677368
# batch:1500; train_loss:1.0715441703796387; val_loss:1.1041655540466309
# batch:1600; train_loss:1.0470303297042847; val_loss:1.0460633039474487
# batch:1700; train_loss:1.0341368913650513; val_loss:1.045912742614746
# batch:1800; train_loss:1.0100644826889038; val_loss:1.0610549449920654
# batch:1900; train_loss:1.013292908668518; val_loss:1.083358645439148
# batch:2000; train_loss:0.989844799041748; val_loss:0.9629979729652405
# batch:2100; train_loss:0.9829205274581909; val_loss:0.9722000956535339
# batch:2200; train_loss:0.9656143188476562; val_loss:0.9961799383163452
# batch:2300; train_loss:0.9517955183982849; val_loss:0.9122050404548645
# batch:2400; train_loss:0.9572030901908875; val_loss:0.9418365359306335
# batch:2500; train_loss:0.9330183267593384; val_loss:0.9334304928779602
# batch:2600; train_loss:0.9259259104728699; val_loss:0.9166167974472046
# batch:2700; train_loss:0.9253029227256775; val_loss:0.9407941699028015
# batch:2800; train_loss:0.9288815855979919; val_loss:0.9967840313911438
# batch:2900; train_loss:0.8964475989341736; val_loss:0.8894816637039185
# batch:3000; train_loss:0.8885027170181274; val_loss:0.9444451928138733
# batch:3100; train_loss:0.8903107047080994; val_loss:0.8731309771537781
# batch:3200; train_loss:0.8692647814750671; val_loss:0.9091603755950928
# batch:3300; train_loss:0.8803463578224182; val_loss:0.9197889566421509
# batch:3400; train_loss:0.8627076148986816; val_loss:0.9064399003982544
# batch:3500; train_loss:0.8681083917617798; val_loss:0.8769476413726807
# batch:3600; train_loss:0.8438926339149475; val_loss:0.9249163269996643
# batch:3700; train_loss:0.8659875988960266; val_loss:0.914946436882019
# batch:3800; train_loss:0.8416768908500671; val_loss:0.8983880877494812
# batch:3900; train_loss:0.8311750292778015; val_loss:0.8906681537628174
# batch:4000; train_loss:0.8367705941200256; val_loss:0.8995881676673889
# batch:4100; train_loss:0.8302457332611084; val_loss:0.8982716202735901
# batch:4200; train_loss:0.815863847732544; val_loss:0.8780359029769897
# batch:4300; train_loss:0.8142790198326111; val_loss:0.8546679615974426
# batch:4400; train_loss:0.7953073382377625; val_loss:0.871731698513031
# batch:4500; train_loss:0.7994257807731628; val_loss:0.8632733225822449
# batch:4600; train_loss:0.8109235167503357; val_loss:0.9241159558296204
# batch:4700; train_loss:0.7879155874252319; val_loss:0.8576215505599976
# batch:4800; train_loss:0.8068389296531677; val_loss:0.8892360925674438
# batch:4900; train_loss:0.7861721515655518; val_loss:0.8603677153587341

# %%
val_output = graphsage.forward(val, True)
val_res = result(g4, val_output, val, idx2label)
Final_evalu(val_res)
# Out:
#                 精确率  召回率        F1  support
# cls
# sms_other       NaN  0.0       NaN        2
# 交易流水＿余额    1.000000  0.5  0.666667        4
# 交易流水＿转账    0.542857  1.0  0.703704       19
# 信用卡＿还款提醒   0.875000  0.7  0.777778       10
# 账号异常＿余额不足  0.500000  1.0  0.666667        2
# 贷前申请＿审核拒绝       NaN  0.0       NaN        2
# 贷前申请＿审核通过       NaN  0.0       NaN        5
# 贷后提醒＿到期提醒       NaN  0.0       NaN        3
# 贷后提醒＿成功放款       NaN  0.0       NaN        3

# %%
val_res
# Out:
#                                                   sms     score       pred  \
# 0   dear customer,in order to serve you better, ax...  0.117413    交易流水＿转账
# 1   you have done a transaction through iob intern...  0.125585    交易流水＿转账
# 2   due, rs.0643 towards your loan a/c x..x6323 in...  0.074077    交易流水＿转账
# 3   a charge of rs. 340.22 has been initiated on y...  0.092606    交易流水＿转账
# 4   dear customer, you have made a payment of rs. ...  0.144008    交易流水＿转账
# 5   rs. 183.02 spent on card xx2186 on 00-40-9641,...  0.117947    交易流水＿转账
# 6   namaskar! your transaction has been declined d...  0.126969  账号异常＿余额不足
# 7   rs. 533.69 was spent on your debit card 7073xx...  0.101295    交易流水＿转账
# 8   your a/c no. xxxxxxxxxx7910 is debited for rs....  0.139235    交易流水＿转账
# 9   rs. 367.30 spent on card xx0956 on 34-89-9890,...  0.137064    交易流水＿转账
# 10  epf balance in a/c no. py/krp/0015848/000/0002...  0.095316    交易流水＿转账
# 11  your transfer claim ( kdmal825960409639 ) has ...  0.108244    交易流水＿转账
# 12  your claim ( kdmal572634591154 ) has been appr...  0.112844    交易流水＿转账
# 13  form 10c (withdrawal benefit) claim id:bgbng17...  0.112978    交易流水＿转账
# 14  your claim form-31 ( ththa18088311 ) has been ...  0.115411    交易流水＿转账
# 15  dear customer, your fund transfer request for ...  0.112314    交易流水＿转账
# 16  your online claim form-31 ( ngaur18095755 ) ha...  0.078489    交易流水＿转账
# 17  dear employer pykrp2115077322 the contribution...  0.074215  账号异常＿扣款失败
# 18  dear member (uan :100220372181), rs. 234 for 6...  0.138680    交易流水＿转账
# 19  your online claim ( kdmal084880714911 ) has be...  0.105502    交易流水＿转账
# 20  dear member, your uan : 100463443315,name :rac...  0.121581    交易流水＿余额
# 21  your claim ththa18088311, settled for rs. 9451...  0.083835    交易流水＿转账
# 22  dear member, your uan : 100654667735,name :man...  0.109912    交易流水＿余额
# 23  hey mazhar uddin khan, your emi of ₹07 is due ...  0.105784   信用卡＿还款提醒
# 24  hey mazhar uddin khan, your emi of ₹35 is due ...  0.133891   信用卡＿还款提醒
# 25  hey kamalesh kumar jain, emi of ₹0671 is due o...  0.088503   信用卡＿还款提醒
# 26  cash deposit transaction of rs. 3828 for accou...  0.138788    交易流水＿转账
# 27  hey deepak bhardwaj, emi of ₹8007 is due on 55...  0.075038  账号异常＿余额不足
# 28  congratulation lalit sharma, we've processed y...  0.074356   信用卡＿还款提醒
# 29  hey mazhar uddin khan, your emi of ₹76 is due ...  0.132470   信用卡＿还款提醒
# 30  hey caroline hanif shaikh, it's repay day! emi...  0.084997    交易流水＿转账
# 31  hey mazhar uddin khan, your emi of ₹66 is due ...  0.109523   信用卡＿还款提醒
# 32  congrats penta raju, your emi plan for loan #5...  0.065675  账号异常＿余额不足
# 33  manjunath.h.m ., you are the best. the payment...  0.083300    交易流水＿转账
# 34  hi, your zestmoney emi application for amazon ...  0.066014    交易流水＿转账
# 35  hey manjunath.h.m, emi of ₹3959 is due on 4240...  0.094358    交易流水＿转账
# 36  hey manjunath.h.m, emi of ₹0885 is due on 4658...  0.118802   信用卡＿还款提醒
# 37  dear customer,ecs transaction of rs. 1256 towa...  0.099678  账号异常＿余额不足
# 38  dear diners cardmember, payment of rs 11603 wa...  0.131317    交易流水＿转账
# 39  your a/c no. xxxxxxxxxx6356 is debited for inr...  0.139870    交易流水＿转账
# 40  reminder! your bill of bharti airtel limited, ...  0.102182    交易流水＿转账
# 41  dear customer. greetings from hdfc bank. we wi...  0.071729    交易流水＿转账
# 42  dear cust, ecs for hdfc bank auto loan#5490701...  0.114094    交易流水＿转账
# 43  dear smartpay customer, please have adequate l...  0.098337    交易流水＿转账
# 44  your a/c no. xxxxxxxxxx7627 is credited by inr...  0.140302    交易流水＿转账
# 45  dear customer, e-stmt for hdfcbank creditcard ...  0.122046   信用卡＿还款提醒
# 46  thank you for using debit card ending 4409 for...  0.085975    交易流水＿转账
# 47  update: your salary of inr 1,624.37 is credite...  0.123008    交易流水＿转账
# 48  dear customer, refund of inr 5.24 from maheshw...  0.131410    交易流水＿转账
# 49  thank you for using debit card ending 5061 for...  0.132326    交易流水＿转账
#
#         label
# 0     交易流水＿余额
# 1     交易流水＿转账
# 2   贷后提醒＿到期提醒
# 3     交易流水＿转账
# 4     交易流水＿转账
# 5     交易流水＿转账
# 6   账号异常＿余额不足
# 7     交易流水＿转账
# 8     交易流水＿转账
# 9     交易流水＿转账
# 10    交易流水＿余额
# 11  贷前申请＿审核通过
# 12  贷前申请＿审核通过
# 13  贷前申请＿审核通过
# 14  贷前申请＿审核通过
# 15    交易流水＿转账
# 16  贷前申请＿审核拒绝
# 17  贷后提醒＿到期提醒
# 18    交易流水＿转账
# 19  贷后提醒＿成功放款
# 20    交易流水＿余额
# 21  贷后提醒＿成功放款
# 22    交易流水＿余额
# 23   信用卡＿还款提醒
# 24   信用卡＿还款提醒
# 25   信用卡＿还款提醒
# 26    交易流水＿转账
# 27   信用卡＿还款提醒
# 28  贷后提醒＿成功放款
# 29   信用卡＿还款提醒
# 30    交易流水＿转账
# 31   信用卡＿还款提醒
# 32  贷前申请＿审核通过
# 33    交易流水＿转账
# 34  贷前申请＿审核拒绝
# 35   信用卡＿还款提醒
# 36   信用卡＿还款提醒
# 37  账号异常＿余额不足
# 38    交易流水＿转账
# 39    交易流水＿转账
# 40   信用卡＿还款提醒
# 41  贷后提醒＿到期提醒
# 42  sms_other
# 43  sms_other
# 44    交易流水＿转账
# 45   信用卡＿还款提醒
# 46    交易流水＿转账
# 47    交易流水＿转账
# 48    交易流水＿转账
# 49    交易流水＿转账

# %%
te_output = graphsage.forward(test_nodes)
test_res = result(g4, te_output, test_nodes, idx2label)
Final_evalu(test_res)
# Out:
#                 精确率       召回率        F1  support
# cls
# sms_other  0.500000  0.250000  0.333333        4
# 交易流水＿余额    0.000000  0.000000       NaN        2
# 交易流水＿转账    0.807692  0.954545  0.875000       66
# 信用卡＿还款提醒   0.444444  0.800000  0.571429        5
# 信用卡＿逾期警告        NaN  0.000000       NaN        3
# 账号异常＿余额不足  0.500000  0.400000  0.444444        5
# 账号异常＿卡号冻结  1.000000  0.200000  0.333333        5
# 账号异常＿扣款失败  0.666667  0.500000  0.571429        4
# 贷前申请＿申请交互       NaN  0.000000       NaN        1
# 贷后提醒＿到期提醒       NaN  0.000000       NaN        3
# 贷后提醒＿逾期催收  0.000000  0.000000       NaN        2

# %%
test_res
# Out:
#                                                   sms     score       pred  \
# 0   thank you for payment of inr.6000.00 on your c...  0.276855   信用卡＿还款提醒
# 1   dear customer,your transaction at atm 1cn04401...  0.653825  账号异常＿余额不足
# 2   your a/c no. xxxxxxx7494 is debited for inr 2,...  0.943611    交易流水＿转账
# 3   your a/c xxxxxxx5273 has been debited with inr...  0.958418    交易流水＿转账
# 4   your a/c no. ***********5885 is credited for r...  0.998221    交易流水＿转账
# 5   inr 9,400.00 credited to your a/c no xxxxxxx49...  0.997619    交易流水＿转账
# 6   dear boi customer, a/c xxxxxxxxxxx6116 charged...  0.246656  sms_other
# 7   rs.30 has been debited from your kotak account...  0.947330    交易流水＿转账
# 8   a/c nn4214 debited for inr 24; atm wdl. a/c ba...  0.946831    交易流水＿转账
# 9   dear customer, refund of rs .82 from hpcl 0.75...  0.845150    交易流水＿转账
# 10  your a/c no. xxxxxxxx1061 is debited for rs.3....  0.981813    交易流水＿转账
# 11  dear customer, payment received for amount of ...  0.453981    交易流水＿转账
# 12  your profile password for username xxxaan has ...  0.639217    交易流水＿转账
# 13  bill payment for ketaki has been made successf...  0.629266    交易流水＿转账
# 14  your a/c no. xxxxxx1711 is credited for rs.20....  0.980808    交易流水＿转账
# 15  pos tran of rs.1522.00 is done on card xx0742 ...  0.649979    交易流水＿转账
# 16  idbi bk a/c. nnnnn64164 credited rs 8000.00 tw...  0.343571    交易流水＿转账
# 17  your a/c no. xxxx651 is debited with rs 199.00...  0.931017    交易流水＿转账
# 18  a/c 3xxxxx6226 debited by rs. 1,500 total bal:...  0.998318    交易流水＿转账
# 19  your a/c no. xxxxxxxxxxx8248 is debited for rs...  0.926966    交易流水＿转账
# 20  hello! your a/c no 60313147 has been credited ...  0.961097    交易流水＿转账
# 21  dear customer, your a/c no. xxxxxxxx9939 is de...  0.987276    交易流水＿转账
# 22  your debit card ending 1471 has been blocked. ...  0.441828    交易流水＿转账
# 23  your fund transfer request for rs. 1000.0 on 2...  0.862515  账号异常＿扣款失败
# 24  you have initiated a txn of inr 415.68 at irct...  0.673878    交易流水＿转账
# 25  your ac xxxxx774561 debited inr 60,000.00 on 3...  0.986156    交易流水＿转账
# 26  hold for inr 10,000.00 created in your ac xxxx...  0.744002    交易流水＿转账
# 27  dear customer, hold has been placed on your ac...  0.549791    交易流水＿转账
# 28  loan of rs. 75000.00 disbursed from loan a/c n...  0.141649  贷后提醒＿逾期催收
# 29  tds of inr 332.00 deducted for interest paid o...  0.751106    交易流水＿转账
# ..                                                ...       ...        ...
# 70  dear customer, a/c xxx1662 charged rs.600 for ...  0.246656  sms_other
# 71  ur transaction on hdfc bank credit card ending...  0.744780    交易流水＿转账
# 72  update: inr 25,000.00 debited from a/c xx0830 ...  0.984129    交易流水＿转账
# 73  dear customer.thank you for your recent paymen...  0.927637    交易流水＿转账
# 74  dear customer,we regret to note that payments ...  0.934523    交易流水＿转账
# 75  dear customer, total amount due on credit card...  0.448800   信用卡＿还款提醒
# 76  your a/c xxxxxxx4289 is debited through atm by...  0.993210    交易流水＿转账
# 77  your a/c xxxx8575 debited rs.149000.00 on 19-0...  0.930200    交易流水＿转账
# 78  returned, chq:940102 for rs.15431.00 fvg capit...  0.406778    交易流水＿转账
# 79  your a/c ...162 in credited inr 21000.00 on 21...  0.963458    交易流水＿转账
# 80  dear customer,your loan a/c 1441***121 with io...  0.183169    交易流水＿转账
# 81  dear customer, cheque 995044 for inr 43000 iss...  0.452082  账号异常＿余额不足
# 82  dear customer,your account xx7410 has been cre...  0.852130    交易流水＿转账
# 83  bank is replacing your existing magstripe debi...  0.214106  账号异常＿卡号冻结
# 84  inr 5,400.00 credited to your a/c no xxxxxxx84...  0.998831    交易流水＿转账
# 85  your indusind bank a/c no.200***439985 has bee...  0.827681    交易流水＿转账
# 86  your a/c no. xxxxxxxx862071 is credited by rs....  0.939250    交易流水＿转账
# 87  dear customer - your neft payment with utr bdb...  0.889841    交易流水＿转账
# 88  your a/c no. xxxx914167 is credited rs.3000.00...  0.960975    交易流水＿转账
# 89  transaction of rs 5000 has been made on kotak ...  0.503710    交易流水＿转账
# 90  inr 1.00 is credited to your a/c xxxx9121 on 1...  0.813458    交易流水＿转账
# 91  you have successfully done a vodafone prepaid ...  0.942593    交易流水＿转账
# 92  hello! you have received refund of transaction...  0.967408    交易流水＿转账
# 93  thanks for applying loan through hdb. your loa...  0.496753    交易流水＿转账
# 94  dear customer, emi of rs 3594 of your cd loan ...  0.332568  贷后提醒＿逾期催收
# 95  your a/c no. xxxxxxxxxxx1608 is debited for rs...  0.964998    交易流水＿转账
# 96  your fund transfer for rs. 6500 on 21-09-18 co...  0.903640  账号异常＿扣款失败
# 97  dear customer, your username avxxxxxh9553 is l...  0.650708    交易流水＿转账
# 98  thanks for rs.4,500.00 received via neft for c...  0.914014    交易流水＿转账
# 99  your debit card 5497xxxxxxxx0600 has been used...  0.776735    交易流水＿转账
#
#         label
# 0     交易流水＿转账
# 1   账号异常＿余额不足
# 2     交易流水＿转账
# 3     交易流水＿转账
# 4     交易流水＿转账
# 5     交易流水＿转账
# 6     交易流水＿转账
# 7     交易流水＿转账
# 8     交易流水＿转账
# 9     交易流水＿转账
# 10    交易流水＿转账
# 11    交易流水＿转账
# 12  账号异常＿卡号冻结
# 13    交易流水＿转账
# 14    交易流水＿转账
# 15    交易流水＿转账
# 16    交易流水＿转账
# 17    交易流水＿转账
# 18    交易流水＿转账
# 19    交易流水＿转账
# 20    交易流水＿转账
# 21    交易流水＿转账
# 22  账号异常＿卡号冻结
# 23  账号异常＿扣款失败
# 24    交易流水＿转账
# 25    交易流水＿转账
# 26    交易流水＿转账
# 27  账号异常＿卡号冻结
# 28  贷后提醒＿到期提醒
# 29    交易流水＿转账
# ..        ...
# 70  sms_other
# 71    交易流水＿转账
# 72    交易流水＿转账
# 73  贷后提醒＿到期提醒
# 74   信用卡＿还款提醒
# 75   信用卡＿还款提醒
# 76    交易流水＿转账
# 77    交易流水＿转账
# 78  sms_other
# 79    交易流水＿转账
# 80  贷后提醒＿逾期催收
# 81  账号异常＿扣款失败
# 82    交易流水＿转账
# 83  账号异常＿卡号冻结
# 84    交易流水＿转账
# 85    交易流水＿转账
# 86    交易流水＿转账
# 87    交易流水＿转账
# 88    交易流水＿转账
# 89    交易流水＿转账
# 90    交易流水＿转账
# 91    交易流水＿转账
# 92    交易流水＿转账
# 93  贷前申请＿申请交互
# 94  贷后提醒＿到期提醒
# 95    交易流水＿转账
# 96  账号异常＿扣款失败
# 97  账号异常＿卡号冻结
# 98    交易流水＿转账
# 99    交易流水＿转账
#
# [100 rows x 4 columns]

# %%
tra_output = graphsage.forward(train)
train_res = result(g4, tra_output, train, idx2label)
Final_evalu(train_res)
# Out:
#                   精确率       召回率        F1  support
# cls
# sms_other    0.564706  0.126984  0.207343      378
# 交易流水＿余额      0.814118  0.590444  0.684471      586
# 交易流水＿转账      0.822938  0.976021  0.892966     6881
# 信用卡＿申请失败          NaN  0.000000       NaN       30
# 信用卡＿还款提醒     0.724897  0.731944  0.728404      720
# 信用卡＿逾期警告     0.612069  0.373684  0.464052      190
# 账号异常＿余额不足    0.711507  0.710356  0.710931      618
# 账号异常＿信用额度不足       NaN  0.000000       NaN       10
# 账号异常＿卡号冻结    1.000000  0.158824  0.274112      170
# 账号异常＿扣款失败    0.795789  0.609677  0.690411      620
# 账户账号＿自己           NaN  0.000000       NaN       10
# 贷前申请＿审核拒绝         NaN  0.000000       NaN       48
# 贷前申请＿审核通过         NaN  0.000000       NaN       85
# 贷前申请＿申请交互         NaN  0.000000       NaN      120
# 贷后提醒＿到期提醒         NaN  0.000000       NaN      197
# 贷后提醒＿成功放款         NaN  0.000000       NaN       37
# 贷后提醒＿逾期催收    0.524345  0.700000  0.599572      200

# %%
train_res
# Out:
#                                                      sms     score       pred  \
# 0      trxn on kotak card xx9287 for rs. 9424 at payu...  0.567944    交易流水＿转账
# 1      please pay overdue amount of rs. 3950 on your ...  0.430323    交易流水＿转账
# 2      dear customer, rs.9.1 has been credited to you...  0.942985    交易流水＿转账
# 3      greetings from rbl bank! your a/c xxxxxxxx5972...  0.422406  账号异常＿余额不足
# 4      you have received a collect request from india...  0.989381    交易流水＿转账
# 5      dear customer, your loan a/c with vijaya bank ...  0.440351  贷后提醒＿逾期催收
# 6      transaction of inr 0537 declined due to insuff...  0.617911  账号异常＿余额不足
# 7      boi - rs 0087.08 credited(trf)loan coll. from ...  0.576000    交易流水＿转账
# 8      inr 785 was spent on your credit card xx3070 o...  0.763487    交易流水＿转账
# 9      thank you for using your sbi debit card 573xx7...  0.460235    交易流水＿转账
# 10     dear customer cash withdrawal limit on your cr...  0.335760    交易流水＿转账
# 11     your a/c xxxx6054 has been debited by rs. 6,28...  0.946141    交易流水＿转账
# 12     from your limit of rs. 35000.00 on your rbl ba...  0.657275    交易流水＿转账
# 13     rs.0,067.51 has been debited from your a/c xx7...  0.957679    交易流水＿转账
# 14     boi-you have received rs.4.13 from finnovation...  0.862843    交易流水＿转账
# 15     greetings from rbl bank! latest transaction do...  0.428173    交易流水＿转账
# 16     chq.no.15 fvg.jai gas age for rs 20340.00 on a...  0.375831   信用卡＿还款提醒
# 17     your a/c 666748 is debited with inr 107.81 on ...  0.969215    交易流水＿转账
# 18     you have done a transaction through iob intern...  0.855702    交易流水＿转账
# 19     an amount of 510 inr has been debited to a/c n...  0.998151    交易流水＿转账
# 20     namaskar! your transaction has been declined d...  0.850565  账号异常＿余额不足
# 21     your a/c xxxx1844 has been debited by rs. 68,4...  0.671702    交易流水＿转账
# 22     dear customer, your loan ref no. 2634723 has b...  0.287677   信用卡＿还款提醒
# 23     boi - rs 5084 has been credited in your accoun...  0.573655    交易流水＿转账
# 24     your a/c no. xxxxxxxx5983 is credited for rs.3...  0.916327    交易流水＿转账
# 25     your a/c no. xxxxxxxxxxxx2291 is debited for r...  0.972496    交易流水＿转账
# 26     dear customer, the available balance for your ...  0.723331    交易流水＿余额
# 27     an amount of inr 69.54 has been debited to you...  0.705444    交易流水＿转账
# 28     your debit card ************9077 has been temp...  0.823000    交易流水＿转账
# 29     paytm has requested rs.863.25 from you. tap he...  0.328710    交易流水＿转账
# ...                                                  ...       ...        ...
# 10870  you have initiated a txn of inr 630.12 at amaz...  0.628214    交易流水＿转账
# 10871  an amount of rs.2,372.39 has been debited from...  0.967455    交易流水＿转账
# 10872  your otp for fund transfer of rs. 17,500.00 fr...  0.247903  账号异常＿余额不足
# 10873  you have initiated a txn of eur 6.30 at skrill...  0.898245    交易流水＿转账
# 10874  we are pleased to inform you that your request...  0.638651    交易流水＿转账
# 10875  your a/c no. xxxxxxxxx8349 is debited for rs. ...  0.987723    交易流水＿转账
# 10876  rs 4779.85 credited to account xxxxx1602 of sb...  0.826965    交易流水＿转账
# 10877  your a/c xx3367 credited inr 8,829.83 on 18-se...  0.971328    交易流水＿转账
# 10878  dear customer, your transaction declined for d...  0.281121  账号异常＿扣款失败
# 10879  chq 104491 for inr 2,430.00 fvr recd in clg wl...  0.401540    交易流水＿转账
# 10880  an amount of rs.6,105.93 has been debited from...  0.969754    交易流水＿转账
# 10881  amount of inr 2,716 credited to acc xxx667361 ...  0.937873    交易流水＿转账
# 10882  dear obc customer, your balance in a/c xxxx343...  0.477728  账号异常＿余额不足
# 10883  your a/c no. xxxxxxx7775 is debited by rs.263....  0.990796    交易流水＿转账
# 10884  dear hdfc bank card member, rs 2.14 has been c...  0.803501    交易流水＿转账
# 10885  dear sbi cardholder, payment of rs. 469.48 for...  0.375007    交易流水＿转账
# 10886  rs 874 was withdrawn at an atm from a/c xx5653...  0.501498    交易流水＿转账
# 10887  your a/c no. xxxxxx5632 is credited for rs. 25...  0.990596    交易流水＿转账
# 10888  rs.830.40 has been debited from your a/c xx183...  0.963228    交易流水＿转账
# 10889  mobile imps transaction of rs 9965.49 to anoop...  0.869749    交易流水＿转账
# 10890  dear hdfcbank cardmember, payment of rs 1228 w...  0.214048  账号异常＿扣款失败
# 10891  your a/c no. xxxxxxxxxxx2284 is credited for r...  0.938823    交易流水＿转账
# 10892  third party transfer to ch chandra shekar rao ...  0.635160    交易流水＿转账
# 10893  rs 55317.85 has been spent on your credit card...  0.902740    交易流水＿转账
# 10894  payment overdue on your credit card xx8254 is ...  0.760312   信用卡＿还款提醒
# 10895  inr 7,732.07 credited to your a/c no xxxxxxx33...  0.998836    交易流水＿转账
# 10896  dear customer,your curr mnth emi for hdbfs loa...  0.171263  贷后提醒＿逾期催收
# 10897  your credit card xx4722 payment of rs.49354.06...  0.595809   信用卡＿还款提醒
# 10898  dear customer, you have a collect request for ...  0.995085    交易流水＿转账
# 10899  boi - we are sorry the transaction from your d...  0.909615  账号异常＿余额不足
#
#            label
# 0      账号异常＿余额不足
# 1      贷后提醒＿逾期催收
# 2        交易流水＿转账
# 3        交易流水＿转账
# 4        交易流水＿转账
# 5      贷后提醒＿逾期催收
# 6      账号异常＿余额不足
# 7        交易流水＿转账
# 8        交易流水＿转账
# 9        交易流水＿转账
# 10     账号异常＿卡号冻结
# 11       交易流水＿转账
# 12       交易流水＿余额
# 13       交易流水＿转账
# 14       交易流水＿转账
# 15       交易流水＿转账
# 16     sms_other
# 17       交易流水＿转账
# 18       交易流水＿转账
# 19       交易流水＿转账
# 20     账号异常＿余额不足
# 21       交易流水＿转账
# 22     贷前申请＿审核通过
# 23       交易流水＿转账
# 24       交易流水＿转账
# 25       交易流水＿转账
# 26       交易流水＿余额
# 27       交易流水＿转账
# 28     账号异常＿卡号冻结
# 29       交易流水＿转账
# ...          ...
# 10870    交易流水＿转账
# 10871    交易流水＿转账
# 10872  sms_other
# 10873    交易流水＿转账
# 10874    交易流水＿转账
# 10875    交易流水＿转账
# 10876    交易流水＿转账
# 10877    交易流水＿转账
# 10878  账号异常＿扣款失败
# 10879  sms_other
# 10880    交易流水＿转账
# 10881    交易流水＿转账
# 10882  账号异常＿余额不足
# 10883    交易流水＿转账
# 10884    交易流水＿转账
# 10885    交易流水＿转账
# 10886    交易流水＿转账
# 10887    交易流水＿转账
# 10888    交易流水＿转账
# 10889    交易流水＿转账
# 10890    交易流水＿转账
# 10891    交易流水＿转账
# 10892    交易流水＿转账
# 10893    交易流水＿转账
# 10894   信用卡＿还款提醒
# 10895    交易流水＿转账
# 10896  贷前申请＿申请交互
# 10897   信用卡＿还款提醒
# 10898    交易流水＿转账
# 10899  账号异常＿余额不足
#
# [10900 rows x 4 columns]
